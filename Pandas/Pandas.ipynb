# %% [markdown]
# # Pandas

# %% [markdown]
# * Pandas is a library for analysing tabular data. It's the sort of analysis you would do on Excel, or using SQL.
# * Numpy is about arrays of homogeneous data, Pandas is about columns of homogeneous data, but overall arranged in a table.
# * Pandas provides objects like DataFrame and GroupBy, which expose methods that allow us to make complex queries in an easy to understand manner.

# %% [markdown]
# > Resources :
# > [10 Minutes to Pandas Tutorial](https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html#min)
# > [Other tutorials](https://pandas.pydata.org/pandas-docs/stable/getting_started/tutorials.html)
# > [The User Guide](https://pandas.pydata.org/pandas-docs/stable/user_guide/index.html)
# > [The API reference](https://pandas.pydata.org/pandas-docs/stable/reference/index.html)

# %% [markdown]
# Pandas will extract the data from that CSV into a DataFrame — a table, basically — then let you do things like:
#
# * Calculate statistics and answer questions about the data, like
# * * What's the average, median, max, or min of each column?
# * * Does column A correlate with column B?
# * * What does the distribution of data in column C look like?
# * Clean the data by doing things like removing missing values and filtering rows or columns by some criteria
# * Visualize the data with help from Matplotlib. Plot bars, lines, histograms, bubbles, and more.
# * Store the cleaned, transformed data back into a CSV, other file or database

# %% [markdown]
# Pandas is built on top of the NumPy package, meaning a lot of the structure of NumPy is used or replicated in Pandas.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## The DataFrame object

# %% [markdown]
# A **Series** is essentially a column, and a **DataFrame** is a multi-dimensional table made up of a collection of Series.

# %% [markdown]
# ### Creating DataFrames from scratch

# %% [markdown]
# There are many ways to create a DataFrame from scratch, but a great option is to just use a simple dict.

# %%
#dict
#Each (key, value) item in data corresponds to a column in the resulting DataFrame.
#pd.DataFrame()
data = {
    'names': [1,2,3,4],
    'location': ['Delhi','','Assam', 'Kerela']
}
df = pd.DataFrame(data)
display(df)
# Out:
#    names location
# 0      1    Delhi
# 1      2
# 2      3    Assam
# 3      4   Kerela

# %%
#The Index of this DataFrame was given to us on creation as the numbers, 
#but we could also create our own when we initialize the DataFrame.
df = pd.DataFrame(data, index=['first','second','third','fourth'])
display(df)
# Out:
#         names location
# first       1    Delhi
# second      2
# third       3    Assam
# fourth      4   Kerela

# %%
#To read a particular row using index/name
#df = pd.DataFrame(data)
#display(df.loc['first'])
df = pd.DataFrame(data)
display(df)
display(df.iloc[0])
# Out:
#    names location
# 0      1    Delhi
# 1      2
# 2      3    Assam
# 3      4   Kerela
# names           1
# location    Delhi
# Name: 0, dtype: object

# %%
# Let's read a CSV and create a DataFrame object from it
# And then let us examine some of its properties
with open("pandas_demo.csv","r") as fi:
    df=pd.read_csv(fi)

# %%
print(type(df))
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     first_name      last_name                       email  gender  \
# 0         Otha         Gjerde      ogjerde0@biglobe.ne.jp  Female
# 1        Yance      Barnsdale   ybarnsdale1@reference.com    Male
# 2      Lazarus        MacNish    lmacnish2@altervista.org    Male
# 3       Monroe        Gwinnel       mgwinnel3@booking.com    Male
# 4      Gaspard      Gullivent       ggullivent4@wikia.com    Male
# ..         ...            ...                         ...     ...
# 995     Eduino  Alessandretti  ealessandrettirn@topsy.com    Male
# 996   Vivianna            Rix              vrixro@sun.com  Female
# 997    Donaugh         Emmert          demmertrp@sohu.com    Male
# 998   Reinaldo     O'Scannill      roscannillrq@desdev.cn    Male
# 999  Justinian          Goney  jgoneyrr@deliciousdays.com    Male
#
#           employer                     designation  \
# 0           Zomato                             NaN
# 1    Goldman Sachs                   Social Worker
# 2              TCS          Administrative Officer
# 3    Goldman Sachs                Technical Writer
# 4          Infosys             Clinical Specialist
# ..             ...                             ...
# 995        Infosys             Structural Engineer
# 996       Flipkart                Quality Engineer
# 997         Google              Recruiting Manager
# 998       Flipkart              VP Quality Control
# 999       Flipkart  Payment Adjustment Coordinator
#
#                                        university personal_phone      bank  \
# 0                           Sang Myung University   132-421-9138      HDFC
# 1            Fachhochschule Ravensburg-Weingarten   492-125-1131       SBI
# 2    California State University, Channel Islands   235-492-4252     ICICI
# 3                   St. Mary-of-the-Woods College            NaN     ICICI
# 4                 Islamic Azad University, Quchan   232-527-4054     ICICI
# ..                                            ...            ...       ...
# 995                     Universidad Adolfo Ibáñez   354-283-0381     ICICI
# 996                             Stonehill College   785-322-0735  Yes Bank
# 997        University of the South Pacific Centre   585-826-1040      HDFC
# 998                      Bulacan State University   268-203-9762     ICICI
# 999                            Arcadia University   173-701-0038  Yes Bank
#
#      birth_year  years_employed
# 0          1970            24.0
# 1          1960            32.0
# 2          1970            24.0
# 3          1982            14.4
# 4          1998             1.6
# ..          ...             ...
# 995        1978            17.6
# 996        1990             8.0
# 997        1962            30.4
# 998        1990             8.0
# 999        1978            17.6
#
# [1000 rows x 11 columns]

# %%
# We can change a column as index as well
#df_col = pd.read_csv('pandas_demo.csv', index_col=0)
df_col = pd.read_csv('pandas_demo.csv')
# or set index after reading a dataset as well
df_col = df_col.set_index('employer')
df_col = df_col.set_index('last_name')
df_col
# Out:
#               first_name                       email  gender  \
# last_name
# Gjerde              Otha      ogjerde0@biglobe.ne.jp  Female
# Barnsdale          Yance   ybarnsdale1@reference.com    Male
# MacNish          Lazarus    lmacnish2@altervista.org    Male
# Gwinnel           Monroe       mgwinnel3@booking.com    Male
# Gullivent        Gaspard       ggullivent4@wikia.com    Male
# ...                  ...                         ...     ...
# Alessandretti     Eduino  ealessandrettirn@topsy.com    Male
# Rix             Vivianna              vrixro@sun.com  Female
# Emmert           Donaugh          demmertrp@sohu.com    Male
# O'Scannill      Reinaldo      roscannillrq@desdev.cn    Male
# Goney          Justinian  jgoneyrr@deliciousdays.com    Male
#
#                                   designation  \
# last_name
# Gjerde                                    NaN
# Barnsdale                       Social Worker
# MacNish                Administrative Officer
# Gwinnel                      Technical Writer
# Gullivent                 Clinical Specialist
# ...                                       ...
# Alessandretti             Structural Engineer
# Rix                          Quality Engineer
# Emmert                     Recruiting Manager
# O'Scannill                 VP Quality Control
# Goney          Payment Adjustment Coordinator
#
#                                                  university personal_phone  \
# last_name
# Gjerde                                Sang Myung University   132-421-9138
# Barnsdale              Fachhochschule Ravensburg-Weingarten   492-125-1131
# MacNish        California State University, Channel Islands   235-492-4252
# Gwinnel                       St. Mary-of-the-Woods College            NaN
# Gullivent                   Islamic Azad University, Quchan   232-527-4054
# ...                                                     ...            ...
# Alessandretti                     Universidad Adolfo Ibáñez   354-283-0381
# Rix                                       Stonehill College   785-322-0735
# Emmert               University of the South Pacific Centre   585-826-1040
# O'Scannill                         Bulacan State University   268-203-9762
# Goney                                    Arcadia University   173-701-0038
#
#                    bank  birth_year  years_employed
# last_name
# Gjerde             HDFC        1970            24.0
# Barnsdale           SBI        1960            32.0
# MacNish           ICICI        1970            24.0
# Gwinnel           ICICI        1982            14.4
# Gullivent         ICICI        1998             1.6
# ...                 ...         ...             ...
# Alessandretti     ICICI        1978            17.6
# Rix            Yes Bank        1990             8.0
# Emmert             HDFC        1962            30.4
# O'Scannill        ICICI        1990             8.0
# Goney          Yes Bank        1978            17.6
#
# [1000 rows x 9 columns]

# %%
#can even read json file.
#pd.read_json()

# %%
#convert back to csv/json
df.to_json('new_data.json')

# %%
# head()
df.head(7)
# Out:
#   first_name  last_name                      email  gender       employer  \
# 0       Otha     Gjerde     ogjerde0@biglobe.ne.jp  Female         Zomato
# 1      Yance  Barnsdale  ybarnsdale1@reference.com    Male  Goldman Sachs
# 2    Lazarus    MacNish   lmacnish2@altervista.org    Male            TCS
# 3     Monroe    Gwinnel      mgwinnel3@booking.com    Male  Goldman Sachs
# 4    Gaspard  Gullivent      ggullivent4@wikia.com    Male        Infosys
# 5      Karna     Climar        kclimar5@boston.com  Female       Flipkart
# 6    Stephen    Gilbert         sgilbert6@hibu.com    Male  Goldman Sachs
#
#                       designation  \
# 0                             NaN
# 1                   Social Worker
# 2          Administrative Officer
# 3                Technical Writer
# 4             Clinical Specialist
# 5                         Teacher
# 6  Payment Adjustment Coordinator
#
#                                      university personal_phone      bank  \
# 0                         Sang Myung University   132-421-9138      HDFC
# 1          Fachhochschule Ravensburg-Weingarten   492-125-1131       SBI
# 2  California State University, Channel Islands   235-492-4252     ICICI
# 3                 St. Mary-of-the-Woods College            NaN     ICICI
# 4               Islamic Azad University, Quchan   232-527-4054     ICICI
# 5                              Patna University   765-164-9307       SBI
# 6                                           NaN   470-960-4961  Yes Bank
#
#    birth_year  years_employed
# 0        1970            24.0
# 1        1960            32.0
# 2        1970            24.0
# 3        1982            14.4
# 4        1998             1.6
# 5        1968            25.6
# 6        1971            23.2

# %%
df.tail(2)
# Out:
#     first_name   last_name                       email gender  employer  \
# 998   Reinaldo  O'Scannill      roscannillrq@desdev.cn   Male  Flipkart
# 999  Justinian       Goney  jgoneyrr@deliciousdays.com   Male  Flipkart
#
#                         designation                university personal_phone  \
# 998              VP Quality Control  Bulacan State University   268-203-9762
# 999  Payment Adjustment Coordinator        Arcadia University   173-701-0038
#
#          bank  birth_year  years_employed
# 998     ICICI        1990             8.0
# 999  Yes Bank        1978            17.6

# %%
df.columns
# Out:
# Index(['first_name', 'last_name', 'email', 'gender', 'employer', 'designation',
#        'university', 'personal_phone', 'bank', 'birth_year', 'years_employed'],
#       dtype='object')

# %%
df.dtypes
# Out:
# first_name         object
# last_name          object
# email              object
# gender             object
# employer           object
# designation        object
# university         object
# personal_phone     object
# bank               object
# birth_year          int64
# years_employed    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   first_name      1000 non-null   object
#  1   last_name       1000 non-null   object
#  2   email           1000 non-null   object
#  3   gender          1000 non-null   object
#  4   employer        1000 non-null   object
#  5   designation     939 non-null    object
#  6   university      892 non-null    object
#  7   personal_phone  783 non-null    object
#  8   bank            1000 non-null   object
#  9   birth_year      1000 non-null   int64
#  10  years_employed  1000 non-null   float64
# dtypes: float64(1), int64(1), object(9)
# memory usage: 86.1+ KB

# %%
df.describe()
# Out:
#         birth_year  years_employed
# count  1000.000000     1000.000000
# mean   1978.382000       17.294400
# std      11.336604        9.069283
# min    1960.000000        1.600000
# 25%    1968.750000        9.600000
# 50%    1978.000000       17.600000
# 75%    1988.000000       25.000000
# max    1998.000000       32.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.values
# Out:
# array([['Otha', 'Gjerde', 'ogjerde0@biglobe.ne.jp', ..., 'HDFC', 1970,
#         24.0],
#        ['Yance', 'Barnsdale', 'ybarnsdale1@reference.com', ..., 'SBI',
#         1960, 32.0],
#        ['Lazarus', 'MacNish', 'lmacnish2@altervista.org', ..., 'ICICI',
#         1970, 24.0],
#        ...,
#        ['Donaugh', 'Emmert', 'demmertrp@sohu.com', ..., 'HDFC', 1962,
#         30.4],
#        ['Reinaldo', "O'Scannill", 'roscannillrq@desdev.cn', ..., 'ICICI',
#         1990, 8.0],
#        ['Justinian', 'Goney', 'jgoneyrr@deliciousdays.com', ...,
#         'Yes Bank', 1978, 17.6]], dtype=object)

# %%
df.shape
# Out:
# (1000, 11)

# %% [markdown]
# #### Handling Duplicates

# %%
# Lets create a duplicate dataframe
temp_df = df.append(df)
print(temp_df.shape)
print(df.shape)
# Out:
# (2000, 11)
# (1000, 11)

# %%
# Drop duplicate
print(temp_df.shape)
#temp_df = temp_df.drop_duplicates(inplace=False)
temp_df.drop_duplicates(inplace=True)
print(temp_df.shape)
# Out:
# (2000, 11)
# (1000, 11)

# %%
# How to drop duplicates? 
# Argument: keep
temp_df = df.append(df)
temp_df.drop_duplicates(inplace=True, keep=False)
temp_df.shape
# Out:
# (0, 11)

# %%
# You can create the dataframe object using the pd.DataFrame() constructor
# Here is one way

a=pd.DataFrame(index=range(0,10),columns=["A first col","B","C",'D'],data=np.random.randint(1,10,(10,4)))
display(a)
# Out:
#    A first col  B  C  D
# 0            8  4  7  5
# 1            6  1  2  4
# 2            8  4  1  8
# 3            7  1  9  1
# 4            5  8  7  4
# 5            3  4  7  5
# 6            1  5  2  9
# 7            2  7  4  9
# 8            4  3  3  6
# 9            6  8  1  2

# %%
# Rename a column
a.rename(columns={'A first col': 'New_A','B':'New_B'}, inplace=True)
a
# Out:
#    New_A  New_B  C  D
# 0      8      4  7  5
# 1      6      1  2  4
# 2      8      4  1  8
# 3      7      1  9  1
# 4      5      8  7  4
# 5      3      4  7  5
# 6      1      5  2  9
# 7      2      7  4  9
# 8      4      3  3  6
# 9      6      8  1  2

# %%
#a.columns 
print(a.columns)
a.columns=['1b','2a','3a','4a']
a.columns
# Out:
# Index(['1a', '2a', '3a', '4a'], dtype='object')
# Index(['1b', '2a', '3a', '4a'], dtype='object')

# %% [markdown]
# ## Reading data

# %% [markdown]
# ### The main interface

# %%
# Columns can be accessed using dot notation
df.birth_year
# Out:
# 0      1970
# 1      1960
# 2      1970
# 3      1982
# 4      1998
#        ...
# 995    1978
# 996    1990
# 997    1962
# 998    1990
# 999    1978
# Name: birth_year, Length: 1000, dtype: int64

# %%
# Columns can also be indexed - This will return a series
df["birth_year"]
# Out:
# 0      1970
# 1      1960
# 2      1970
# 3      1982
# 4      1998
#        ...
# 995    1978
# 996    1990
# 997    1962
# 998    1990
# 999    1978
# Name: birth_year, Length: 1000, dtype: int64

# %%
print(type(df))
print(type(df.birth_year))
print(type(df['birth_year']))
print(type(df[['birth_year']]))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
# Multiple columns can also be indexed - This will return a DataFrame
display(df[["first_name","birth_year"]].head())
print(type(df[["first_name","birth_year"]]))
# Out:
#   first_name  birth_year
# 0       Otha        1970
# 1      Yance        1960
# 2    Lazarus        1970
# 3     Monroe        1982
# 4    Gaspard        1998
# <class 'pandas.core.frame.DataFrame'>

# %%
# You can slice the rows by position
sliced=df[50:100]
# Note that the index still keeps the old numbers
# Thus index itself is kind of like a series - it's not just numbering from top to bottom.
# Actually, the index can be strings, dates anything
# Though for simplicity we will stick to integer indexes
print(sliced.index)
sliced.head()
# Out:
# RangeIndex(start=50, stop=100, step=1)
#    first_name last_name                      email  gender       employer  \
# 50     Kirbie  Cannavan     kcannavan1e@elpais.com  Female       Flipkart
# 51      Matty   Winston     mwinston1f@dedecms.com  Female            TCS
# 52   Thurston    Hyrons  thyrons1g@yellowpages.com    Male  Goldman Sachs
# 53      Neila     Cerie       ncerie1h@nbcnews.com  Female            TCS
# 54     Curtis     Blunt    cblunt1i@vistaprint.com    Male            TCS
#
#                      designation                  university personal_phone  \
# 50                     Paralegal   Universitas Mahendradatta   679-436-6607
# 51                Civil Engineer         Amravati University   218-816-7201
# 52             Director of Sales  Hirosaki Gakuin University   166-627-6986
# 53  Computer Systems Analyst III                         NaN            NaN
# 54       Automation Specialist I     Aichi Gakuin University   300-805-2393
#
#         bank  birth_year  years_employed
# 50  Yes Bank        1983            13.6
# 51      HDFC        1995             4.0
# 52       SBI        1977            18.4
# 53     ICICI        1977            18.4
# 54  Yes Bank        1990             8.0

# %%
# You can chain the two indexing style
df[["first_name","last_name"]].head()
# Out:
#   first_name  last_name
# 0       Otha     Gjerde
# 1      Yance  Barnsdale
# 2    Lazarus    MacNish
# 3     Monroe    Gwinnel
# 4    Gaspard  Gullivent

# %% [markdown]
# To summarise, indexing the dataframe directly like ``df[]`` allows
# * indexing a single column by name (or label)
# * indexing a list of columns by name
# * slicing of rows by position.
#
# Note that the following things doesn't work
# * indexing columns by position
# * indexing/slicing rows by name/label
#
# As we will see, there are two other interfaces that give us this functionality.

# %% [markdown]
# ### .loc

# %%
# Index a column by name same as before
# Notice that now you have to compulsarily provide a slice for the rows
df.loc[39:50,["first_name","last_name"]].head()
#df.loc[:, "first_name"]
# Out:
#    first_name   last_name
# 39     Ashlen       Pirie
# 40     Garner    Winspear
# 41      Caryn      Livoir
# 42        Ugo  Mablestone
# 43    Rudolfo    Rudinger

# %%
# But let's look at rows
sliced=df[50:100]
# Note the index goes from 50 to 100
sliced.head(6)
# Out:
#    first_name last_name                      email  gender       employer  \
# 50     Kirbie  Cannavan     kcannavan1e@elpais.com  Female       Flipkart
# 51      Matty   Winston     mwinston1f@dedecms.com  Female            TCS
# 52   Thurston    Hyrons  thyrons1g@yellowpages.com    Male  Goldman Sachs
# 53      Neila     Cerie       ncerie1h@nbcnews.com  Female            TCS
# 54     Curtis     Blunt    cblunt1i@vistaprint.com    Male            TCS
# 55    Opalina  Danilyak    odanilyak1j@auda.org.au  Female       Flipkart
#
#                      designation                  university personal_phone  \
# 50                     Paralegal   Universitas Mahendradatta   679-436-6607
# 51                Civil Engineer         Amravati University   218-816-7201
# 52             Director of Sales  Hirosaki Gakuin University   166-627-6986
# 53  Computer Systems Analyst III                         NaN            NaN
# 54       Automation Specialist I     Aichi Gakuin University   300-805-2393
# 55            Research Associate      Mount Aloysius College   106-346-6386
#
#         bank  birth_year  years_employed
# 50  Yes Bank        1983            13.6
# 51      HDFC        1995             4.0
# 52       SBI        1977            18.4
# 53     ICICI        1977            18.4
# 54  Yes Bank        1990             8.0
# 55     ICICI        1976            19.2

# %%
# We can index by position with the main interface - for example : 0:5 returns 50-54
sliced[0:5]
# Out:
#    first_name last_name                      email  gender       employer  \
# 50     Kirbie  Cannavan     kcannavan1e@elpais.com  Female       Flipkart
# 51      Matty   Winston     mwinston1f@dedecms.com  Female            TCS
# 52   Thurston    Hyrons  thyrons1g@yellowpages.com    Male  Goldman Sachs
# 53      Neila     Cerie       ncerie1h@nbcnews.com  Female            TCS
# 54     Curtis     Blunt    cblunt1i@vistaprint.com    Male            TCS
#
#                      designation                  university personal_phone  \
# 50                     Paralegal   Universitas Mahendradatta   679-436-6607
# 51                Civil Engineer         Amravati University   218-816-7201
# 52             Director of Sales  Hirosaki Gakuin University   166-627-6986
# 53  Computer Systems Analyst III                         NaN            NaN
# 54       Automation Specialist I     Aichi Gakuin University   300-805-2393
#
#         bank  birth_year  years_employed
# 50  Yes Bank        1983            13.6
# 51      HDFC        1995             4.0
# 52       SBI        1977            18.4
# 53     ICICI        1977            18.4
# 54  Yes Bank        1990             8.0

# %%
# But can we slice with respect to the original index?
print(sliced.shape)
# This will return an empty DF, as position is only upto 50
display(sliced[55:60])
# Out:
# (50, 11)
# Empty DataFrame
# Columns: [first_name, last_name, email, gender, employer, designation, university, personal_phone, bank, birth_year, years_employed]
# Index: []

# %%
# But this works well
sliced.loc[55:58]
# Out:
#    first_name last_name                    email  gender  employer  \
# 55    Opalina  Danilyak  odanilyak1j@auda.org.au  Female  Flipkart
# 56      Lilly  Espadero    lespadero1k@lycos.com  Female   Infosys
# 57  Evangelia   Crebbin    ecrebbin1l@sphinn.com  Female    Zomato
# 58        Kim  Dumbrall       kdumbrall1m@ed.gov  Female  Flipkart
#
#             designation                                university  \
# 55   Research Associate                    Mount Aloysius College
# 56  Assistant Professor                Univesidade Agostinho Neto
# 57         Developer IV              Universidade Federal do Pará
# 58  Staff Accountant II  Southern Taiwan University of Technology
#
#    personal_phone      bank  birth_year  years_employed
# 55   106-346-6386     ICICI        1976            19.2
# 56   520-107-4136     ICICI        1976            19.2
# 57   507-542-2830     ICICI        1971            23.2
# 58   242-522-5669  Yes Bank        1960            32.0

# %%
# Sometimes the original index is useful, especially if you want to modify the slice
# and assign to the original DataFrame (it automatically matches the indexes)

# But sometimes after a slice you want to reset the index
sliced=sliced.reset_index()
sliced
# Out:
#     level_0  index first_name     last_name  \
# 0         0     50     Kirbie      Cannavan
# 1         1     51      Matty       Winston
# 2         2     52   Thurston        Hyrons
# 3         3     53      Neila         Cerie
# 4         4     54     Curtis         Blunt
# 5         5     55    Opalina      Danilyak
# 6         6     56      Lilly      Espadero
# 7         7     57  Evangelia       Crebbin
# 8         8     58        Kim      Dumbrall
# 9         9     59       Mick      Caulkett
# 10       10     60   Leonardo     Medendorp
# 11       11     61   Shirleen          Best
# 12       12     62      Sayre        Thomel
# 13       13     63    Kandace         Poole
# 14       14     64      Keefe       Battman
# 15       15     65   Morganne      Persence
# 16       16     66      Danny      Ivanchin
# 17       17     67     Nickie      Deaville
# 18       18     68       Judd      McMullen
# 19       19     69      Lemmy      Alenikov
# 20       20     70      Rubin         Straw
# 21       21     71    Tristam     Rowbottam
# 22       22     72       Pail     MacPhaden
# 23       23     73      Sella   Tomaszynski
# 24       24     74      Vanda        Elloit
# 25       25     75      Inigo           Eim
# 26       26     76        Gar       Scholes
# 27       27     77     Vinson       Calvard
# 28       28     78     Joshua      Daventry
# 29       29     79   Courtney   Labuschagne
# 30       30     80      Biddy       Brugden
# 31       31     81     Sanson           Ren
# 32       32     82     Kattie      Fritchly
# 33       33     83       Pooh     Vallender
# 34       34     84   Annabela       Berkery
# 35       35     85      Kalie      Knowller
# 36       36     86      Lucky         Tousy
# 37       37     87  Margarita      Bartunek
# 38       38     88     Hamnet        Seeler
# 39       39     89   Fernando         Crole
# 40       40     90       Addy      Schaffel
# 41       41     91      Geoff       Jesteco
# 42       42     92    Katusha    Salzberger
# 43       43     93      Misti     Gaukrodge
# 44       44     94      Jerry  Hickenbottom
# 45       45     95      Flory     Mellhuish
# 46       46     96     Anthia      Woodroof
# 47       47     97   Marybeth          Kach
# 48       48     98      Josey        Dacres
# 49       49     99  Harrietta        Ralphs
#
#                                 email  gender       employer  \
# 0              kcannavan1e@elpais.com  Female       Flipkart
# 1              mwinston1f@dedecms.com  Female            TCS
# 2           thyrons1g@yellowpages.com    Male  Goldman Sachs
# 3                ncerie1h@nbcnews.com  Female            TCS
# 4             cblunt1i@vistaprint.com    Male            TCS
# 5             odanilyak1j@auda.org.au  Female       Flipkart
# 6               lespadero1k@lycos.com  Female        Infosys
# 7               ecrebbin1l@sphinn.com  Female         Zomato
# 8                  kdumbrall1m@ed.gov  Female       Flipkart
# 9               mcaulkett1n@google.fr    Male  Goldman Sachs
# 10            lmedendorp1o@apache.org    Male         Google
# 11                  sbest1p@skype.com  Female            TCS
# 12         sthomel1q@biblegateway.com    Male         Google
# 13           kpoole1r@arstechnica.com  Female       Flipkart
# 14                 kbattman1s@163.com    Male         Google
# 15   mpersence1t@networksolutions.com  Female        Infosys
# 16       divanchin1u@businessweek.com    Male  Goldman Sachs
# 17            ndeaville1v@storify.com    Male            TCS
# 18              jmcmullen1w@jigsy.com    Male         Google
# 19       lalenikov1x@domainmarket.com    Male         Google
# 20           rstraw1y@nydailynews.com    Male         Google
# 21            trowbottam1z@weebly.com    Male            TCS
# 22         pmacphaden20@geocities.com    Male            TCS
# 23            stomaszynski21@java.com  Female         Zomato
# 24               velloit22@unicef.org  Female       Flipkart
# 25                     ieim23@mtv.com    Male         Google
# 26                 gscholes24@nba.com    Male        Infosys
# 27  vcalvard25@nationalgeographic.com    Male         Google
# 28               jdaventry26@ning.com    Male       Flipkart
# 29           clabuschagne27@salon.com  Female         Google
# 30     bbrugden28@acquirethisname.com  Female       Flipkart
# 31                       sren29@de.vu    Male        Infosys
# 32       kfritchly2a@surveymonkey.com  Female       Flipkart
# 33         pvallender2b@delicious.com  Female            TCS
# 34         aberkery2c@tripadvisor.com  Female         Zomato
# 35            kknowller2d@squidoo.com  Female       Flipkart
# 36       ltousy2e@creativecommons.org  Female            TCS
# 37            mbartunek2f@comcast.net  Female  Goldman Sachs
# 38            hseeler2g@posterous.com    Male            TCS
# 39                  fcrole2h@1und1.de    Male        Infosys
# 40                aschaffel2i@mit.edu  Female         Zomato
# 41                 gjesteco2j@cmu.edu    Male        Infosys
# 42            ksalzberger2k@prlog.org  Female            TCS
# 43             mgaukrodge2l@state.gov  Female  Goldman Sachs
# 44            jhickenbottom2m@epa.gov    Male       Flipkart
# 45         fmellhuish2n@csmonitor.com  Female            TCS
# 46             awoodroof2o@disqus.com  Female        Infosys
# 47                  mkach2p@webmd.com  Female            TCS
# 48            jdacres2q@bigcartel.com  Female         Google
# 49                  hralphs2r@loc.gov  Female         Google
#
#                              designation  \
# 0                              Paralegal
# 1                         Civil Engineer
# 2                      Director of Sales
# 3           Computer Systems Analyst III
# 4                Automation Specialist I
# 5                     Research Associate
# 6                    Assistant Professor
# 7                           Developer IV
# 8                    Staff Accountant II
# 9                  Chief Design Engineer
# 10                    Environmental Tech
# 11                      Dental Hygienist
# 12                       General Manager
# 13  Business Systems Development Analyst
# 14             Automation Specialist III
# 15                 VP Product Management
# 16                      Web Developer II
# 17                    Analyst Programmer
# 18                         Geologist III
# 19                    Environmental Tech
# 20                     Marketing Manager
# 21                      Registered Nurse
# 22               Senior Quality Engineer
# 23                        Programmer III
# 24               Senior Quality Engineer
# 25                  Help Desk Technician
# 26                    Analyst Programmer
# 27                         Senior Editor
# 28                                   NaN
# 29                    VP Quality Control
# 30                     Chemical Engineer
# 31                      Media Manager IV
# 32                     Assistant Manager
# 33                              VP Sales
# 34                 Chief Design Engineer
# 35                                 Nurse
# 36                               Teacher
# 37                                   NaN
# 38                    Analyst Programmer
# 39                          VP Marketing
# 40                  Programmer Analyst I
# 41                         VP Accounting
# 42                      Health Coach III
# 43                       Data Coordiator
# 44               GIS Technical Architect
# 45                     Financial Analyst
# 46                          Food Chemist
# 47            Desktop Support Technician
# 48            Quality Control Specialist
# 49               Human Resources Manager
#
#                                            university personal_phone  \
# 0                           Universitas Mahendradatta   679-436-6607
# 1                                 Amravati University   218-816-7201
# 2                          Hirosaki Gakuin University   166-627-6986
# 3                                                 NaN            NaN
# 4                             Aichi Gakuin University   300-805-2393
# 5                              Mount Aloysius College   106-346-6386
# 6                          Univesidade Agostinho Neto   520-107-4136
# 7                        Universidade Federal do Pará   507-542-2830
# 8            Southern Taiwan University of Technology   242-522-5669
# 9                             Chiba Keizai University            NaN
# 10                   Academy of Public Administration   937-606-4664
# 11                        Universitas Negeri Makassar   411-534-2933
# 12     Instituto Superior Politécnico e Universitário   456-711-9429
# 13                 Chongqing University of Technology   933-584-3069
# 14                           University of Nottingham            NaN
# 15                        Jinnah University for Women   237-691-6567
# 16                             Al Muthanna University   542-144-0801
# 17         Hochschule für Jüdische Studien Heidelberg   567-837-6420
# 18                              Baiko Women's College   611-200-3834
# 19                        University of South Alabama   258-193-1656
# 20                   Global Business School Barcelona   560-719-2254
# 21                                  Africa University   302-747-5343
# 22                                  Mars Hill College            NaN
# 23           Universidad Panamericana de San Salvador   809-222-9712
# 24                              Universidad Don Bosco            NaN
# 25                 Universidad Privada Antenor Orrego   551-332-6082
# 26                       University of King's College            NaN
# 27                             Université de Djibouti   394-799-6816
# 28                  Perm State Pharmaceutical Academy   655-752-8878
# 29                             Namik Kemal University            NaN
# 30                                 Kangnam University            NaN
# 31                                    Bond University   820-936-6917
# 32  Universidad de la Fraternidad de Agrupaciones ...   552-885-7716
# 33                               Universidad Nacional   115-819-8016
# 34                    Illinois Benedictine University   765-322-4804
# 35                               University of Jordan   495-538-3175
# 36                       National Hispanic University   831-344-5447
# 37                                 Universidad ISALUD   804-243-6763
# 38                 Universidad Catolica de Valparaiso   816-782-5655
# 39                        Shanghai Medical University   182-882-4663
# 40                               University of Rijeka   435-290-8381
# 41                            Shaikh Zayed University            NaN
# 42                Southeast Missouri State University   724-642-6071
# 43  Moscow State Automobile and Road Technical Uni...   782-192-5693
# 44                      Azerbaijan Medical University   956-366-4088
# 45                  Abubakar Tafawa Balewa University   395-973-3554
# 46                                 Azzahra University   685-691-1424
# 47                              University of Iceland   250-738-3623
# 48                          Mokpo National University   996-353-4956
# 49                                      Smith College   477-564-8526
#
#         bank  birth_year  years_employed
# 0   Yes Bank        1983            13.6
# 1       HDFC        1995             4.0
# 2        SBI        1977            18.4
# 3      ICICI        1977            18.4
# 4   Yes Bank        1990             8.0
# 5      ICICI        1976            19.2
# 6      ICICI        1976            19.2
# 7      ICICI        1971            23.2
# 8   Yes Bank        1960            32.0
# 9        SBI        1991             7.2
# 10      HDFC        1977            18.4
# 11     ICICI        1970            24.0
# 12  Yes Bank        1995             4.0
# 13  Yes Bank        1989             8.8
# 14     ICICI        1993             5.6
# 15       SBI        1997             2.4
# 16     ICICI        1967            26.4
# 17      HDFC        1979            16.8
# 18       SBI        1979            16.8
# 19     ICICI        1975            20.0
# 20  Yes Bank        1962            30.4
# 21       SBI        1998             1.6
# 22       SBI        1988             9.6
# 23      HDFC        1969            24.8
# 24  Yes Bank        1990             8.0
# 25       SBI        1969            24.8
# 26     ICICI        1963            29.6
# 27       SBI        1987            10.4
# 28     ICICI        1968            25.6
# 29      HDFC        1979            16.8
# 30  Yes Bank        1984            12.8
# 31       SBI        1996             3.2
# 32       SBI        1973            21.6
# 33  Yes Bank        1984            12.8
# 34       SBI        1971            23.2
# 35  Yes Bank        1986            11.2
# 36      HDFC        1981            15.2
# 37  Yes Bank        1983            13.6
# 38       SBI        1993             5.6
# 39       SBI        1982            14.4
# 40      HDFC        1994             4.8
# 41  Yes Bank        1961            31.2
# 42  Yes Bank        1968            25.6
# 43  Yes Bank        1964            28.8
# 44  Yes Bank        1998             1.6
# 45  Yes Bank        1962            30.4
# 46       SBI        1962            30.4
# 47  Yes Bank        1996             3.2
# 48       SBI        1993             5.6
# 49      HDFC        1972            22.4

# %% [markdown]
# ### .iloc

# %%
# This is good ol' numpy style indexing 
# By position on rows
# and By position on columns
df.iloc[5:10,2:5]
# Out:
#                      email  gender       employer
# 5      kclimar5@boston.com  Female       Flipkart
# 6       sgilbert6@hibu.com    Male  Goldman Sachs
# 7  pbeverage7@sakura.ne.jp  Female       Flipkart
# 8         anutton8@cnn.com  Female        Infosys
# 9        flagen9@yandex.ru  Female         Zomato

# %%
# A value
df.iloc[5,0:3]
# Out:
# first_name                  Karna
# last_name                  Climar
# email         kclimar5@boston.com
# Name: 5, dtype: object

# %%
# A series
df.iloc[:5,1]
# Out:
# 0       Gjerde
# 1    Barnsdale
# 2      MacNish
# 3      Gwinnel
# 4    Gullivent
# Name: last_name, dtype: object

# %%
# also a series
df.iloc[5,1:6]
# Out:
# last_name                   Climar
# email          kclimar5@boston.com
# gender                      Female
# employer                  Flipkart
# designation                Teacher
# Name: 5, dtype: object

# %%
df.loc[:,["first_name"]]
# Out:
#     first_name
# 0         Otha
# 1        Yance
# 2      Lazarus
# 3       Monroe
# 4      Gaspard
# ..         ...
# 995     Eduino
# 996   Vivianna
# 997    Donaugh
# 998   Reinaldo
# 999  Justinian
#
# [1000 rows x 1 columns]

# %% [markdown]
# #### Handle Missing Values

# %% [markdown]
# There are two options in dealing with nulls:
#
# * Get rid of rows or columns with nulls
# * Replace nulls with non-null values, a technique known as imputation

# %%
# isnull() returns a DataFrame where each cell is either True or False depending on that cell's null status.
display(df.isnull())
# Out:
#      first_name  last_name  email  gender  employer  designation  university  \
# 0         False      False  False   False     False         True       False
# 1         False      False  False   False     False        False       False
# 2         False      False  False   False     False        False       False
# 3         False      False  False   False     False        False       False
# 4         False      False  False   False     False        False       False
# ..          ...        ...    ...     ...       ...          ...         ...
# 995       False      False  False   False     False        False       False
# 996       False      False  False   False     False        False       False
# 997       False      False  False   False     False        False       False
# 998       False      False  False   False     False        False       False
# 999       False      False  False   False     False        False       False
#
#      personal_phone   bank  birth_year  years_employed
# 0             False  False       False           False
# 1             False  False       False           False
# 2             False  False       False           False
# 3              True  False       False           False
# 4             False  False       False           False
# ..              ...    ...         ...             ...
# 995           False  False       False           False
# 996           False  False       False           False
# 997           False  False       False           False
# 998           False  False       False           False
# 999           False  False       False           False
#
# [1000 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# first_name          0
# last_name           0
# email               0
# gender              0
# employer            0
# designation        61
# university        108
# personal_phone    217
# bank                0
# birth_year          0
# years_employed      0
# dtype: int64

# %%
# Removing Null Values
print(df.shape)
display(df.dropna().head(2))
print(df.dropna().shape)
print(df.shape)
# Out:
# (1000, 11)
#   first_name  last_name                      email gender       employer  \
# 1      Yance  Barnsdale  ybarnsdale1@reference.com   Male  Goldman Sachs
# 2    Lazarus    MacNish   lmacnish2@altervista.org   Male            TCS
#
#               designation                                    university  \
# 1           Social Worker          Fachhochschule Ravensburg-Weingarten
# 2  Administrative Officer  California State University, Channel Islands
#
#   personal_phone   bank  birth_year  years_employed
# 1   492-125-1131    SBI        1960            32.0
# 2   235-492-4252  ICICI        1970            24.0
# (658, 11)
# (1000, 11)

# %%
# How to drop NA values?
# Argument: Axis
display(df.dropna(axis=1))
tp_df = df.dropna(axis=1)
display(tp_df.isnull().sum())
# Out:
#     first_name      last_name                       email  gender  \
# 0         Otha         Gjerde      ogjerde0@biglobe.ne.jp  Female
# 1        Yance      Barnsdale   ybarnsdale1@reference.com    Male
# 2      Lazarus        MacNish    lmacnish2@altervista.org    Male
# 3       Monroe        Gwinnel       mgwinnel3@booking.com    Male
# 4      Gaspard      Gullivent       ggullivent4@wikia.com    Male
# ..         ...            ...                         ...     ...
# 995     Eduino  Alessandretti  ealessandrettirn@topsy.com    Male
# 996   Vivianna            Rix              vrixro@sun.com  Female
# 997    Donaugh         Emmert          demmertrp@sohu.com    Male
# 998   Reinaldo     O'Scannill      roscannillrq@desdev.cn    Male
# 999  Justinian          Goney  jgoneyrr@deliciousdays.com    Male
#
#           employer      bank  birth_year  years_employed
# 0           Zomato      HDFC        1970            24.0
# 1    Goldman Sachs       SBI        1960            32.0
# 2              TCS     ICICI        1970            24.0
# 3    Goldman Sachs     ICICI        1982            14.4
# 4          Infosys     ICICI        1998             1.6
# ..             ...       ...         ...             ...
# 995        Infosys     ICICI        1978            17.6
# 996       Flipkart  Yes Bank        1990             8.0
# 997         Google      HDFC        1962            30.4
# 998       Flipkart     ICICI        1990             8.0
# 999       Flipkart  Yes Bank        1978            17.6
#
# [1000 rows x 8 columns]
# first_name        0
# last_name         0
# email             0
# gender            0
# employer          0
# bank              0
# birth_year        0
# years_employed    0
# dtype: int64

# %%
# Imputation
# Get a column => assign value for na cells => fillna()
uni = df['university']
#display(uni[27:39])
na_value = 'uni_modified'
uni.fillna(na_value, inplace=True)
#display(df[27:39])
df.loc[28, 'university'] = 'uni_new'
df.loc[28]
# Out:
# first_name                            Toma
# last_name                             Orme
# email                     tormes@google.ru
# gender                              Female
# employer                            Zomato
# designation       Senior Financial Analyst
# university                         uni_new
# personal_phone                207-579-9571
# bank                              Yes Bank
# birth_year                            1991
# years_employed                         7.2
# Name: 28, dtype: object

# %% [markdown]
# ### Boolean indexing

# %%
# boolean indexing by column
#print(df['birth_year']>=1990)
display(df[(df['birth_year']>1990) & (df['birth_year']<1999)].head())
# multiple conditions
display(df[df['employer'].isin(['Infosys','Zomato'])].head())
# Out:
#    first_name   last_name                       email  gender       employer  \
# 4     Gaspard   Gullivent       ggullivent4@wikia.com    Male        Infosys
# 14      Anica  MacIlhargy        amacilhargye@nih.gov  Female         Zomato
# 18      Hermy  Lambertini  hlambertinii@bloglovin.com    Male            TCS
# 20       Amii   Sacchetti        asacchettik@ucla.edu  Female        Infosys
# 24       Tome   McCreadie       tmccreadieo@wired.com    Male  Goldman Sachs
#
#             designation                       university personal_phone  \
# 4   Clinical Specialist  Islamic Azad University, Quchan   232-527-4054
# 14   Analyst Programmer               Capitol University   578-536-7874
# 18   Environmental Tech           Warnborough University   715-183-6507
# 20   Recruiting Manager              Hyupsung University            NaN
# 24   Recruiting Manager      London Guildhall University   542-135-4800
#
#         bank  birth_year  years_employed
# 4      ICICI        1998             1.6
# 14  Yes Bank        1997             2.4
# 18       SBI        1994             4.8
# 20     ICICI        1997             2.4
# 24     ICICI        1991             7.2
#    first_name  last_name                   email  gender employer  \
# 0        Otha     Gjerde  ogjerde0@biglobe.ne.jp  Female   Zomato
# 4     Gaspard  Gullivent   ggullivent4@wikia.com    Male  Infosys
# 8     Abigail     Nutton        anutton8@cnn.com  Female  Infosys
# 9      Faunie      Lagen       flagen9@yandex.ru  Female   Zomato
# 10    Vitoria     Sammes        vsammesa@mlb.com  Female   Zomato
#
#                   designation                            university  \
# 0                         NaN                 Sang Myung University
# 4         Clinical Specialist       Islamic Azad University, Quchan
# 8                    Operator             Sapporo Gakuin University
# 9    Software Test Engineer I              Texas Woman's University
# 10  Automation Specialist III  Ternopil Academy of National Economy
#
#    personal_phone   bank  birth_year  years_employed
# 0    132-421-9138   HDFC        1970            24.0
# 4    232-527-4054  ICICI        1998             1.6
# 8    715-488-1959  ICICI        1971            23.2
# 9    940-133-9120    SBI        1961            31.2
# 10   340-509-3716  ICICI        1965            28.0

# %%
# boolean indexing by column
#print(df['birth_year']>=1990)
only_90s_kids=df[df.birth_year>=1990]
#print(only_90s_kids)
only_90s_kids=only_90s_kids[only_90s_kids.birth_year<=2000]
print(len(only_90s_kids))
only_90s_kids.head(5)
# Out:
# 225
#    first_name   last_name                       email  gender employer  \
# 4     Gaspard   Gullivent       ggullivent4@wikia.com    Male  Infosys
# 11    Hermann       Dewen          hdewenb@hao123.com    Male   Zomato
# 14      Anica  MacIlhargy        amacilhargye@nih.gov  Female   Zomato
# 18      Hermy  Lambertini  hlambertinii@bloglovin.com    Male      TCS
# 20       Amii   Sacchetti        asacchettik@ucla.edu  Female  Infosys
#
#             designation                       university personal_phone  \
# 4   Clinical Specialist  Islamic Azad University, Quchan   232-527-4054
# 11   VP Quality Control    Universidade de Caxias do Sul            NaN
# 14   Analyst Programmer               Capitol University   578-536-7874
# 18   Environmental Tech           Warnborough University   715-183-6507
# 20   Recruiting Manager              Hyupsung University            NaN
#
#         bank  birth_year  years_employed
# 4      ICICI        1998             1.6
# 11  Yes Bank        1990             8.0
# 14  Yes Bank        1997             2.4
# 18       SBI        1994             4.8
# 20     ICICI        1997             2.4

# %% [markdown]
# ## Setting data

# %%
# The most common operation : computing a new column based on other columns

only_90s_kids["age"] = 2020 - only_90s_kids.birth_year

# Notice how the index is preserved
only_90s_kids.head(5)
# Out:
#    first_name   last_name                       email  gender employer  \
# 4     Gaspard   Gullivent       ggullivent4@wikia.com    Male  Infosys
# 11    Hermann       Dewen          hdewenb@hao123.com    Male   Zomato
# 14      Anica  MacIlhargy        amacilhargye@nih.gov  Female   Zomato
# 18      Hermy  Lambertini  hlambertinii@bloglovin.com    Male      TCS
# 20       Amii   Sacchetti        asacchettik@ucla.edu  Female  Infosys
#
#             designation                       university personal_phone  \
# 4   Clinical Specialist  Islamic Azad University, Quchan   232-527-4054
# 11   VP Quality Control    Universidade de Caxias do Sul            NaN
# 14   Analyst Programmer               Capitol University   578-536-7874
# 18   Environmental Tech           Warnborough University   715-183-6507
# 20   Recruiting Manager              Hyupsung University            NaN
#
#         bank  birth_year  years_employed  age
# 4      ICICI        1998             1.6   22
# 11  Yes Bank        1990             8.0   30
# 14  Yes Bank        1997             2.4   23
# 18       SBI        1994             4.8   26
# 20     ICICI        1997             2.4   23

# %%
# You could even have assigned it to the original df

# but let's copy it first ;)
fresh_df=df.copy()

# All the correct indices will be filled otherwise it will be set as NaN.
# This is one of the use cases of having a separate index object
# vs just position numbering like numpy
fresh_df["age"] = 2020 - only_90s_kids.birth_year
fresh_df
# Out:
#     first_name      last_name                       email  gender  \
# 0         Otha         Gjerde      ogjerde0@biglobe.ne.jp  Female
# 1        Yance      Barnsdale   ybarnsdale1@reference.com    Male
# 2      Lazarus        MacNish    lmacnish2@altervista.org    Male
# 3       Monroe        Gwinnel       mgwinnel3@booking.com    Male
# 4      Gaspard      Gullivent       ggullivent4@wikia.com    Male
# ..         ...            ...                         ...     ...
# 995     Eduino  Alessandretti  ealessandrettirn@topsy.com    Male
# 996   Vivianna            Rix              vrixro@sun.com  Female
# 997    Donaugh         Emmert          demmertrp@sohu.com    Male
# 998   Reinaldo     O'Scannill      roscannillrq@desdev.cn    Male
# 999  Justinian          Goney  jgoneyrr@deliciousdays.com    Male
#
#           employer                     designation  \
# 0           Zomato                             NaN
# 1    Goldman Sachs                   Social Worker
# 2              TCS          Administrative Officer
# 3    Goldman Sachs                Technical Writer
# 4          Infosys             Clinical Specialist
# ..             ...                             ...
# 995        Infosys             Structural Engineer
# 996       Flipkart                Quality Engineer
# 997         Google              Recruiting Manager
# 998       Flipkart              VP Quality Control
# 999       Flipkart  Payment Adjustment Coordinator
#
#                                        university personal_phone      bank  \
# 0                           Sang Myung University   132-421-9138      HDFC
# 1            Fachhochschule Ravensburg-Weingarten   492-125-1131       SBI
# 2    California State University, Channel Islands   235-492-4252     ICICI
# 3                   St. Mary-of-the-Woods College            NaN     ICICI
# 4                 Islamic Azad University, Quchan   232-527-4054     ICICI
# ..                                            ...            ...       ...
# 995                     Universidad Adolfo Ibáñez   354-283-0381     ICICI
# 996                             Stonehill College   785-322-0735  Yes Bank
# 997        University of the South Pacific Centre   585-826-1040      HDFC
# 998                      Bulacan State University   268-203-9762     ICICI
# 999                            Arcadia University   173-701-0038  Yes Bank
#
#      birth_year  years_employed   age
# 0          1970            24.0   NaN
# 1          1960            32.0   NaN
# 2          1970            24.0   NaN
# 3          1982            14.4   NaN
# 4          1998             1.6  22.0
# ..          ...             ...   ...
# 995        1978            17.6   NaN
# 996        1990             8.0  30.0
# 997        1962            30.4   NaN
# 998        1990             8.0  30.0
# 999        1978            17.6   NaN
#
# [1000 rows x 12 columns]

# %%
# You can of course set values at a particular position
print(fresh_df.iloc[0,-1]) 
fresh_df.iloc[0,-1]=29
print(fresh_df.iloc[0,-1])
# Out:
# nan
# 29.0

# %% [markdown]
# # Data Investigation Example 1

# %% [markdown]
# Let's make a set of questions and then see how we can answer them by using pandas

# %% [markdown]
# * Who are the employers?
# * What is the employee count of each employer?
# * What is the % of Male vs Female employees for each company?
# * What is the average age of an employee for each company?
# * Which bank is most popular in each company?

# %%
df[:]["employer"].drop_duplicates()
# Out:
# 0            Zomato
# 1     Goldman Sachs
# 2               TCS
# 4           Infosys
# 5          Flipkart
# 31           Google
# Name: employer, dtype: object

# %%
grps=df.groupby(by="employer")
print(grps)
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f04885e19a0>

# %%
grps.groups
# Out:
# {'Flipkart': Int64Index([  5,   7,  13,  21,  25,  27,  33,  40,  50,  55,
#              ...
#              957, 962, 966, 970, 981, 985, 991, 996, 998, 999],
#             dtype='int64', length=167),
#  'Goldman Sachs': Int64Index([  1,   3,   6,  15,  16,  22,  23,  24,  26,  36,
#              ...
#              951, 956, 960, 961, 973, 974, 975, 982, 986, 988],
#             dtype='int64', length=168),
#  'Google': Int64Index([ 31,  34,  43,  60,  62,  64,  68,  69,  70,  75,
#              ...
#              924, 932, 934, 950, 958, 964, 978, 979, 989, 997],
#             dtype='int64', length=186),
#  'Infosys': Int64Index([  4,   8,  20,  29,  32,  35,  38,  48,  56,  65,
#              ...
#              953, 954, 968, 969, 971, 977, 980, 987, 990, 995],
#             dtype='int64', length=162),
#  'TCS': Int64Index([  2,  18,  19,  30,  39,  42,  45,  51,  53,  54,
#              ...
#              931, 933, 935, 939, 949, 952, 963, 965, 983, 993],
#             dtype='int64', length=168),
#  'Zomato': Int64Index([  0,   9,  10,  11,  12,  14,  17,  28,  49,  57,
#              ...
#              925, 945, 955, 959, 967, 972, 976, 984, 992, 994],
#             dtype='int64', length=149)}

# %%
# Notice that it counts non-empty values
grps.count()
# Out:
#                first_name  last_name  email  gender  designation  university  \
# employer
# Flipkart              167        167    167     167          158         155
# Goldman Sachs         168        168    168     168          151         152
# Google                186        186    186     186          175         163
# Infosys               162        162    162     162          155         144
# TCS                   168        168    168     168          163         149
# Zomato                149        149    149     149          137         129
#
#                personal_phone  bank  birth_year  years_employed
# employer
# Flipkart                  134   167         167             167
# Goldman Sachs             131   168         168             168
# Google                    146   186         186             186
# Infosys                   120   162         162             162
# TCS                       139   168         168             168
# Zomato                    113   149         149             149

# %%
# So how to get the number of rows in each group?

# One way:
fresh=df.copy()
fresh["id"]=np.arange(0,len(fresh))
display(fresh)
print(fresh.groupby("employer").count())
print(fresh.groupby("employer").count()["id"])

# Another simpler way :)
display(grps.size())
# Out:
#     first_name      last_name                       email  gender  \
# 0         Otha         Gjerde      ogjerde0@biglobe.ne.jp  Female
# 1        Yance      Barnsdale   ybarnsdale1@reference.com    Male
# 2      Lazarus        MacNish    lmacnish2@altervista.org    Male
# 3       Monroe        Gwinnel       mgwinnel3@booking.com    Male
# 4      Gaspard      Gullivent       ggullivent4@wikia.com    Male
# ..         ...            ...                         ...     ...
# 995     Eduino  Alessandretti  ealessandrettirn@topsy.com    Male
# 996   Vivianna            Rix              vrixro@sun.com  Female
# 997    Donaugh         Emmert          demmertrp@sohu.com    Male
# 998   Reinaldo     O'Scannill      roscannillrq@desdev.cn    Male
# 999  Justinian          Goney  jgoneyrr@deliciousdays.com    Male
#
#           employer                     designation  \
# 0           Zomato                             NaN
# 1    Goldman Sachs                   Social Worker
# 2              TCS          Administrative Officer
# 3    Goldman Sachs                Technical Writer
# 4          Infosys             Clinical Specialist
# ..             ...                             ...
# 995        Infosys             Structural Engineer
# 996       Flipkart                Quality Engineer
# 997         Google              Recruiting Manager
# 998       Flipkart              VP Quality Control
# 999       Flipkart  Payment Adjustment Coordinator
#
#                                        university personal_phone      bank  \
# 0                           Sang Myung University   132-421-9138      HDFC
# 1            Fachhochschule Ravensburg-Weingarten   492-125-1131       SBI
# 2    California State University, Channel Islands   235-492-4252     ICICI
# 3                   St. Mary-of-the-Woods College            NaN     ICICI
# 4                 Islamic Azad University, Quchan   232-527-4054     ICICI
# ..                                            ...            ...       ...
# 995                     Universidad Adolfo Ibáñez   354-283-0381     ICICI
# 996                             Stonehill College   785-322-0735  Yes Bank
# 997        University of the South Pacific Centre   585-826-1040      HDFC
# 998                      Bulacan State University   268-203-9762     ICICI
# 999                            Arcadia University   173-701-0038  Yes Bank
#
#      birth_year  years_employed   id
# 0          1970            24.0    0
# 1          1960            32.0    1
# 2          1970            24.0    2
# 3          1982            14.4    3
# 4          1998             1.6    4
# ..          ...             ...  ...
# 995        1978            17.6  995
# 996        1990             8.0  996
# 997        1962            30.4  997
# 998        1990             8.0  998
# 999        1978            17.6  999
#
# [1000 rows x 12 columns]
#                first_name  last_name  email  gender  designation  university  \
# employer
# Flipkart              167        167    167     167          158         155
# Goldman Sachs         168        168    168     168          151         152
# Google                186        186    186     186          175         163
# Infosys               162        162    162     162          155         144
# TCS                   168        168    168     168          163         149
# Zomato                149        149    149     149          137         129
#
#                personal_phone  bank  birth_year  years_employed   id
# employer
# Flipkart                  134   167         167             167  167
# Goldman Sachs             131   168         168             168  168
# Google                    146   186         186             186  186
# Infosys                   120   162         162             162  162
# TCS                       139   168         168             168  168
# Zomato                    113   149         149             149  149
# employer
# Flipkart         167
# Goldman Sachs    168
# Google           186
# Infosys          162
# TCS              168
# Zomato           149
# Name: id, dtype: int64
# employer
# Flipkart         167
# Goldman Sachs    168
# Google           186
# Infosys          162
# TCS              168
# Zomato           149
# dtype: int64

# %%
grps=df.groupby(by=["employer","gender"])

# This is an example of a hierarchical index for a series
display(grps.size())
# Out:
# employer       gender
# Flipkart       Female    86
#                Male      81
# Goldman Sachs  Female    85
#                Male      83
# Google         Female    91
#                Male      95
# Infosys        Female    82
#                Male      80
# TCS            Female    92
#                Male      76
# Zomato         Female    72
#                Male      77
# dtype: int64

# %%
counts=pd.DataFrame(grps.size())
print(counts.to_records())
counts=pd.DataFrame(counts.to_records())
display(counts)
# Out:
# [('Flipkart', 'Female', 86) ('Flipkart', 'Male', 81)
#  ('Goldman Sachs', 'Female', 85) ('Goldman Sachs', 'Male', 83)
#  ('Google', 'Female', 91) ('Google', 'Male', 95) ('Infosys', 'Female', 82)
#  ('Infosys', 'Male', 80) ('TCS', 'Female', 92) ('TCS', 'Male', 76)
#  ('Zomato', 'Female', 72) ('Zomato', 'Male', 77)]
#          employer  gender   0
# 0        Flipkart  Female  86
# 1        Flipkart    Male  81
# 2   Goldman Sachs  Female  85
# 3   Goldman Sachs    Male  83
# 4          Google  Female  91
# 5          Google    Male  95
# 6         Infosys  Female  82
# 7         Infosys    Male  80
# 8             TCS  Female  92
# 9             TCS    Male  76
# 10         Zomato  Female  72
# 11         Zomato    Male  77

# %%
with_age=df.copy()
with_age["age"]=2020 - with_age.birth_year
with_age[["employer","age"]].groupby("employer").mean()
# Out:
#                      age
# employer
# Flipkart       41.616766
# Goldman Sachs  41.047619
# Google         43.000000
# Infosys        42.382716
# TCS            39.005952
# Zomato         42.651007

# %%
temp=df[["employer","bank"]].groupby(["employer","bank"]).size()
temp=pd.DataFrame(pd.DataFrame(temp).to_records())
temp=temp.rename(columns={"0":"count"})
temp=temp.sort_values('count',ascending=False)
display(temp)
# Out:
#          employer      bank  count
# 8          Google      HDFC     55
# 10         Google       SBI     55
# 14        Infosys       SBI     51
# 2        Flipkart       SBI     47
# 0        Flipkart      HDFC     46
# 17            TCS     ICICI     45
# 18            TCS       SBI     45
# 4   Goldman Sachs      HDFC     44
# 22         Zomato       SBI     44
# 16            TCS      HDFC     43
# 6   Goldman Sachs       SBI     42
# 7   Goldman Sachs  Yes Bank     42
# 11         Google  Yes Bank     42
# 13        Infosys     ICICI     42
# 5   Goldman Sachs     ICICI     40
# 1        Flipkart     ICICI     39
# 21         Zomato     ICICI     37
# 23         Zomato  Yes Bank     37
# 15        Infosys  Yes Bank     36
# 19            TCS  Yes Bank     35
# 3        Flipkart  Yes Bank     35
# 9          Google     ICICI     34
# 12        Infosys      HDFC     33
# 20         Zomato      HDFC     31

# %%
# Some more creativity
display(temp.drop_duplicates(subset=["employer"],keep="first"))
# Out:
#          employer   bank  count
# 8          Google   HDFC     55
# 14        Infosys    SBI     51
# 2        Flipkart    SBI     47
# 17            TCS  ICICI     45
# 4   Goldman Sachs   HDFC     44
# 22         Zomato    SBI     44
