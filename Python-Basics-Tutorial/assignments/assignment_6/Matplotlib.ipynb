# %% [markdown]
# # Matplotlib

# %% [markdown]
# > Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python.
#
# * In simple words - a library to plot data in various ways.
# * With matplotlib you can
#     * make line plots, scatter plots, pie charts, bar charts, matrix visualization etc
#     * plot in 2d as well as 3d
#     * draw and display arbitrary images in python
# * matplotlib works with numpy arrays - i.e. the data to plot is numpy arrays.
# * Generally everything is done using the ``matplotlib.pyplot`` module - which has most of the functions that we will need.

# %% [markdown]
# To install matplotlib run the following command in your python environment
#
# ``pip install matplotlib``
#
# To import matplotlib, we will be rather importing the submodule pyplt

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# > **Resources**
# > * [An overview of matplotlib](https://matplotlib.org/tutorials/introductory/usage.html)
# > The above resource is advanced, but you can read the sections
# > A simple example, Parts of a Figure, Backends : What is a backend?
# > * [The pyplot tutorial](https://matplotlib.org/tutorials/introductory/pyplot.html)
# > Definitely read through the pyplot tutorial
# > * [A list of all the functions in pyplt](https://matplotlib.org/api/pyplot_summary.html)
# > You should definitely go through this list and check out 10-15 functions to get a feel for what is possible with matplotlib
# > * [The gallery of examples](https://matplotlib.org/gallery/index.html)

# %% [markdown]
# ### Some simple plots

# %%
# plot y=x
num_samples=20
x=np.linspace(20,100,num_samples) # 10 samples between 2 and 10 # input vector
y=x # output vector to be equal to x 
_=plt.plot(x,y)

# %%
# plot y=sin(x)
num_samples=2000
x=np.linspace(2,10,num_samples) # input vector x
#print(x)
y=np.log(x)  #output vector
_=plt.plot(x,y)

# %% [markdown]
# Matplotlib graphs your data on Figures (i.e., windows, Jupyter widgets, etc.), <br>
# each of which can contain one or more Axes (i.e., an area where points can be specified in terms of x-y coordinates (or theta-r in a polar plot, or x-y-z in a 3D plot, etc.). <br>
#     <br>The most simple way of creating a figure with an axes is using pyplot.subplots. We can then use Axes.plot to draw some data on the axes:

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Plot some data on the axes.

# %%
#There is a corresponding function in the matplotlib.pyplot module 
#that performs that plot on the "current" axes, creating that axes (and its parent figure) if they don't exist
#So the previous example can be written more shortly as
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Matplotlib plot.

# %%
# plot arbitrary lines
x=np.round(np.random.uniform(0,10,10),decimals=1)
y=np.round(np.random.uniform(0,10,10),decimals=1)
#print(list(zip(x,y)))
plt.figure(figsize=(10,10))
_=plt.plot(x,y)

# %%
x=np.round(np.random.uniform(0,10,10),decimals=1)
y=np.round(np.random.uniform(0,10,10),decimals=1)
z=np.round(np.random.uniform(0,10,10),decimals=1)
print(list(zip(x,y,z)))
# Out:
# [(1.0, 5.2, 9.6), (2.7, 8.5, 5.0), (9.1, 8.8, 0.5), (5.1, 5.0, 5.3), (1.4, 8.4, 4.2), (9.1, 4.6, 6.4), (7.8, 8.3, 5.3), (6.8, 8.8, 2.2), (1.1, 2.0, 9.1), (1.2, 5.0, 5.1)]

# %%
# plot multiple lines 

num_samples=5
num_lines=10
for i in range(0,num_lines):
    x=np.linspace(2,10,num_samples) #initialising the input array
    y=(i/num_lines)*x + 1 #initialise the output array
    print(y)
    _=plt.plot(x,y) #plot thm together
# Out:
# [1. 1. 1. 1. 1.]
# [1.2 1.4 1.6 1.8 2. ]
# [1.4 1.8 2.2 2.6 3. ]
# [1.6 2.2 2.8 3.4 4. ]
# [1.8 2.6 3.4 4.2 5. ]
# [2. 3. 4. 5. 6.]
# [2.2 3.4 4.6 5.8 7. ]
# [2.4 3.8 5.2 6.6 8. ]
# [2.6 4.2 5.8 7.4 9. ]
# [ 2.8  4.6  6.4  8.2 10. ]

# %%
# plot multiple lines with labels

num_samples=5
num_lines=10
for i in range(0,num_lines):
    x=np.linspace(2,10,num_samples)
    y=(i/num_lines)*x + 1
    _=plt.plot(x,y,label="slope_"+str(i)) # plt.plot(x,y, label='slope_'+str(i))
_=plt.legend()

# %%
x = 5
y =15

def add(n1, n2):
    result = n1+n2
    print(result)
    return n1-n2
x = add(x,y)
print(x)
# Out:
# 20
# -10

# %%
# plot a circle
num_samples=200
x=np.linspace(-1,1,num_samples) # 100 samples between -1 and 1
y=np.sqrt(1-x**2) #initialise the output
plt.plot(x,y)
plt.plot(x,-y)

# %% [markdown]
# Plot: Requires continuous data along both Axis.
# What if we want to plot point?

# %%
plt.scatter(x,y)

# %%
# scatter plot
num_samples=10
data=np.random.uniform(1,5,(num_samples,2)) # data is a 2d np array of shape(10,2)
print(data.shape)
plt.scatter(data[:,0],data[:,1]) # plot x,y coordinates using 1dim as x and 2dim as y

num_samples=5
data=np.random.uniform(10,15,(num_samples,2))
print(data.shape)
_=plt.scatter(data[:,0],data[:,1])

num_samples=100
data=np.random.uniform(20,25,(num_samples,2))
print(data.shape)
_=plt.scatter(data[:,0],data[:,1])
#plt.scatter
#ax.scatter
# Out:
# (10, 2)
# (5, 2)
# (100, 2)

# %% [markdown]
# ## Parts of a figure
#
# * Title
# * Legend
# * Grid
# * X Label
# * Y Label
# * Ticks

# %% [markdown]
# <div><img src="https://matplotlib.org/_images/anatomy.png" width=500px style="margin-left:0;"></div>

# %% [markdown]
# Source : https://matplotlib.org/tutorials/introductory/usage.html

# %% [markdown]
# ### Changing the default formatting of your figure

# %%
# line labels, colors and markers
# adding a legend
# fmt
num_samples=500
x=np.linspace(-1,1,num_samples)
y=np.sqrt(1-x**2)
plt.figure(figsize=(10,10))
plt.scatter(x,y,label="top",marker="x",color="green") #plt.plot(x,y, label='legend/info', marker, )
plt.plot(x,-y,label="bottom",marker="o",color="black",linewidth="5",markersize=10,markerfacecolor="r")
_=plt.legend()

# %%
# title, ticks, labels, grid
num_samples=20
x=np.linspace(-1,1,num_samples)
y=np.sqrt(1-x**2)
plt.figure(figsize=(10,10))
plt.plot(x,y,label="top",marker="x",color="r")
plt.plot(x,-y,label="bottom",marker="o",color="b")

plt.title("A circle: This is the title")
plt.xlabel("this is x label")
plt.ylabel("this is y label")

plt.xticks(np.linspace(-2,2,25))
plt.yticks(np.linspace(-1,1,5))

_=plt.legend()

# %%
# scatter markers
# scatter size

# scatter plot
num_samples=50
data=np.random.uniform(1,3.5,(num_samples,2))
print(data.shape)

alphas = np.linspace(0.1, 1, num_samples)
rgba_colors = np.zeros((num_samples,4))
# for red the first column needs to be one
rgba_colors[:,0] = 1.0
# the fourth column needs to be your alphas
rgba_colors[:, 3] = alphas

plt.figure(figsize=(10,10))
plt.scatter(data[:,0],data[:,1],c=rgba_colors,s=40,marker="o",label="women")

num_samples=50
data=np.random.uniform(2,5,(num_samples,2))
print(data.shape)
markersizes=np.linspace(10,80,num_samples)
#print(markersizes)
plt.scatter(data[:,0],data[:,1],c="g",s=markersizes,marker='s',label="men")
#plt.scatter(data[:,0],data[:,1],c=rgba_colors,s=markersizes,marker='s',label="men")

plt.title("Analysis of pro basketball performance w.r.t height, gender, and age")
plt.xlabel("average score")
plt.ylabel("height")
_=plt.legend()
# Out:
# (50, 2)
# (50, 2)

# %%
x = np.linspace(0, 2, 100)

# Note that even in the OO-style, we use `.pyplot.figure` to create the figure.
fig, ax = plt.subplots(1,1)  # Create a figure and an axes.
ax.plot(x, x, label='linear')  # Plot some data on the axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.plot(x, x**4, label='fourth')  # ... and some more.
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.legend()  # Add a legend.

# %% [markdown]
# * What if we want seperate graph in seperate figure?

# %%
x = np.linspace(0, 2, 100)


#fig, ax = plt.subplots() = fig, ax = plt.suplots(1,1)

# Note that even in the OO-style, we use `.pyplot.figure` to create the figure.
fig, ax = plt.subplots(2,2)  # Create a figure and an axes.
ax[0][0].plot(x, x, label='linear', color='orange')  # Plot some data on the axes.
ax[0][1].plot(x, x**2, label='quadratic', color='red')  # Plot more data on the axes...
ax[1,0].plot(x, x**3, label='cubic', color='g')  # ... and some more.
ax[1][1].plot(x, x**4, label='fourth')  # ... and some more.
#ax.set_xlabel('x label')  # Add an x-label to the axes.
#ax.set_ylabel('y label')  # Add a y-label to the axes.
#ax.set_title("Simple Plot")  # Add a title to the axes.
#ax.legend()  # Add a legend.

# %% [markdown]
# ### Subplots

# %%
import math 

num_samples=150

# subplots example
NUM_PLOTS=8
num_columns=4
num_rows=NUM_PLOTS//4
fig,axes=plt.subplots(num_rows,num_columns,figsize=(4*num_columns,4*num_rows))
print(axes)
for i in range(0,NUM_PLOTS):
    myax=axes[math.floor(i/num_columns)][i%num_columns]
    myax.set_title("y=x^"+str(i),fontweight="bold",size="12")
    x=np.linspace(-5,5,num_samples)
    y=x**i
    myax.plot(x,y,color="r")
# Out:
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc48fc73a50>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x7fc48fa5e950>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x7fc48fa11150>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x7fc48fa39910>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc48f9eb110>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x7fc48f9948d0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x7fc48f9491d0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x7fc48f973990>]]

# %% [markdown]
# # More numpy examples

# %% [markdown]
# ### Example 1 : Drawing a regular polygon

# %%
# generate points in order (theta) and plot
num_sides=6
radius=1
theta=2*np.pi/num_sides * np.arange(0,num_sides+1,1)
x=radius * np.cos(theta)
y=radius * np.sin(theta)
plt.figure(figsize=(10,10))
plt.plot(x,y)

# %% [markdown]
# ### Example 2 : Manipulating Images

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
# load image into numpy array
img=mpimg.imread("./car1.jpeg")
#print(img,img.dtype,img.shape)
plt.figure(figsize=(10,10))
plt.imshow(img)

# %%
# rgb to greyscale
# scale b/w 0 to 1
avg_image=np.sum(img,axis=2)/3
avg_image=avg_image.astype('uint8')
#print(avg_image,avg_image.dtype,avg_image.shape)
plt.figure(figsize=(10,10))
plt.imshow(avg_image, cmap='gray',vmin=255, vmax=255)

# %%
# discretize greyscale
block_size=255/1
disc_img=np.round((avg_image/block_size))
disc_img=np.round(disc_img*block_size)
#print(disc_img)
disc_img=disc_img.astype('uint8')
plt.figure(figsize=(10,10))
plt.imshow(disc_img,cmap='gray', vmin=100, vmax=255)

# %%
# frame 

x=np.linspace(-1,1,img.shape[1])
#print(x.shape)
X=np.tile(x,reps=(img.shape[0],1))
print(X.shape)
y=np.linspace(-1,1,img.shape[0]).reshape(-1,1)
#print(y.shape)
Y=np.tile(y,reps=(1,img.shape[1]))
print(Y.shape)
circle=X**2 + Y**2 <1  # circle if img.shape[0]==img.shape[1] otherwise ellipse
plt.imshow(circle*255)

framed_image=np.where(circle, avg_image, 0)
plt.figure(figsize=(10,10))
plt.imshow(framed_image,cmap='gray', vmin=0, vmax=255)
# Out:
# (914, 1024)
# (914, 1024)

# %%
# discretize colors
red_channel=np.where(np.argmax(img,axis=2)==0,255,0)
print(red_channel)
red = img[:,:,0]
print(red)
plt.figure(figsize=(10,10))
plt.imshow(red)

red_channel=np.expand_dims(red_channel,axis=2)
print(red_channel.shape)

green_channel=np.where(np.argmax(img,axis=2)==1,255,0)
green_channel=np.expand_dims(green_channel,axis=2)

blue_channel=np.where(np.argmax(img,axis=2)==2,255,0)
blue_channel=np.expand_dims(blue_channel,axis=2)

discrete_color=np.concatenate([red_channel,green_channel,blue_channel],axis=2)
#plt.figure(figsize=(10,10))
#plt.imshow(discrete_color)
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# [[133 138 140 ...  93  87  93]
#  [135 139 141 ...  88  91  91]
#  [130 133 134 ...  89  96  83]
#  ...
#  [ 65  65  62 ...  73  80  79]
#  [ 61  61  69 ...  70  72  76]
#  [ 57  58  67 ...  72  72  75]]
# (914, 1024, 1)

# %% [markdown]
# ### Example 3 : Writing Vectorized Code

# %% [markdown]
# * Matrix multiplication

# %%
d1=100
d2=100
d3=100
x=np.random.randint(1,5,d1*d2).reshape(d1,d2)
y=np.random.randint(1,5,d2*d3).reshape(d2,d3)
print(x)
print("\n\n")
print(y)
# Out:
# [[3 1 2 ... 4 2 2]
#  [2 4 2 ... 2 3 3]
#  [4 1 4 ... 3 4 4]
#  ...
#  [2 3 4 ... 1 3 2]
#  [1 4 4 ... 4 2 3]
#  [1 3 3 ... 4 2 2]]
#
#
#
# [[1 2 3 ... 4 1 2]
#  [4 2 4 ... 3 4 2]
#  [2 3 1 ... 1 1 1]
#  ...
#  [3 2 2 ... 1 3 4]
#  [4 2 1 ... 2 3 4]
#  [3 2 3 ... 4 3 4]]

# %%
import time

# %% [markdown]
# The **assert** keyword is used when debugging code. <br>
# The assert keyword lets you test if a condition in your code returns True, if not, the program will raise an AssertionError.

# %%
# function for product of ith row and jth col
# Equaivalent to matrix prod: mat1 @ mat2 or mat1.dot(mat2)
def calculate_entry(mat1,mat2,i,j):
    assert(mat1.shape[1]==mat2.shape[0])
    common_dim=mat1.shape[1]
    # ith row 
    product_sum=0
    for posn in range(0,common_dim):
        product_sum+=mat1[i,posn]* mat2[posn,j]
    return product_sum

# %%
# 2 x loop + function
dim1 = x.shape[0]
dim2 = x.shape[1]
assert(dim2==y.shape[0])
dim3 = y.shape[1]
result1 = np.zeros((dim1,dim3))
start=time.time()
for i in range(0,dim1):
    for j in range(0,dim3):
        result1[i,j]=calculate_entry(x,y,i,j)
print(time.time()-start)
# Out:
# 0.6140742301940918

# %%
# replace function with slice + elementwise multiplication
dim1 = x.shape[0]
dim2 = x.shape[1]
assert(dim2==y.shape[0])
dim3 = y.shape[1]
result2 = np.zeros((dim1,dim3))
start=time.time()
for i in range(0,dim1):
    for j in range(0,dim3):
        result2[i,j]=np.sum(x[i,:]*y[:,j])
print(time.time()-start)
# Out:
# 0.08905982971191406

# %%
# check same
np.all(result1==result2)
# Out:
# True

# %%
# np.dot
start=time.time()
result3=np.dot(x,y)
print(time.time()-start)
# Out:
# 0.0030846595764160156

# %%
# check same
np.all(result1==result3)
# Out:
# True

# %% [markdown]
# * difference calculation

# %%
# function for product of ith row and jth col
def calculate_row_difference(mat1,mat2,i,j):
    assert(mat1.shape[1]==mat2.shape[1])
    feature_len=mat1.shape[1]
    # ith row 
    diff_sum=0
    for posn in range(0,feature_len):
        diff_sum+=np.abs(mat1[i,posn]-mat2[j,posn])
    return diff_sum

# %%
# 2 x loop + function
num_rows1 = x.shape[0]
feature_len = x.shape[1]
num_rows3 = y.shape[0]
assert(feature_len==y.shape[1])
result2 = np.zeros((num_rows1,num_rows3))
start=time.time()
for i in range(0,num_rows1):
    for j in range(0,num_rows3):
        result1[i,j]=calculate_row_difference(x,y,i,j)
print(time.time()-start)
# Out:
# 1.5468480587005615

# %%
# difference vectorized
num_rows1 = x.shape[0]
feature_len = x.shape[1]
num_rows3 = y.shape[0]
assert(feature_len==y.shape[1])
result2 = np.zeros((num_rows1,num_rows3))
start=time.time()
for i in range(0,num_rows1):
    for j in range(0,num_rows3):
        result2[i,j]=np.sum(np.abs(x[i,:]-y[j,:]))
print(time.time()-start)
# Out:
# 0.07019686698913574

# %%
np.all(result1==result2)
# Out:
# True

# %%
# using broadcasting voodoo
num_rows1 = x.shape[0]
feature_len = x.shape[1]
num_rows2 = y.shape[0]
start=time.time()
mat1=x.reshape(num_rows1,1,feature_len)
mat2=y.reshape(1,num_rows2,feature_len)
diff=mat1-mat2
diff=np.abs(diff)
result3=np.sum(diff,axis=2)
print(time.time()-start)
# Out:
# 0.012514829635620117

# %%
np.all(result1==result3)
# Out:
# True
