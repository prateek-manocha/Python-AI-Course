# %% [markdown]
# # Pandas

# %% [markdown]
# * Pandas is a library for analysing tabular data. It's the sort of analysis you would do on Excel, or using SQL.
# * Numpy is about arrays of homogeneous data, Pandas is about columns of homogeneous data, but overall arranged in a table.
# * Pandas provides objects like DataFrame and GroupBy, which expose methods that allow us to make complex queries in an easy to understand manner.

# %% [markdown]
# > Resources :
# > [10 Minutes to Pandas Tutorial](https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html#min)
# > [Other tutorials](https://pandas.pydata.org/pandas-docs/stable/getting_started/tutorials.html)
# > [The User Guide](https://pandas.pydata.org/pandas-docs/stable/user_guide/index.html)
# > [The API reference](https://pandas.pydata.org/pandas-docs/stable/reference/index.html)

# %% [markdown]
# Pandas will extract the data from that CSV into a DataFrame — a table, basically — then let you do things like:
#
# * Calculate statistics and answer questions about the data, like
# * * What's the average, median, max, or min of each column?
# * * Does column A correlate with column B?
# * * What does the distribution of data in column C look like?
# * Clean the data by doing things like removing missing values and filtering rows or columns by some criteria
# * Visualize the data with help from Matplotlib. Plot bars, lines, histograms, bubbles, and more.
# * Store the cleaned, transformed data back into a CSV, other file or database

# %% [markdown]
# Pandas is built on top of the NumPy package, meaning a lot of the structure of NumPy is used or replicated in Pandas.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## The DataFrame object

# %% [markdown]
# A **Series** is essentially a column, and a **DataFrame** is a multi-dimensional table made up of a collection of Series.

# %% [markdown]
# ### Creating DataFrames from scratch

# %% [markdown]
# There are many ways to create a DataFrame from scratch, but a great option is to just use a simple dict.

# %%
#dict
#Each (key, value) item in data corresponds to a column in the resulting DataFrame.
#pd.DataFrame()

# %%
#The Index of this DataFrame was given to us on creation as the numbers, 
#but we could also create our own when we initialize the DataFrame.
#pd.DataFrame(df, index=[])

# %%
#To read a particular row using index/name

# %%
# Let's read a CSV and create a DataFrame object from it
# And then let us examine some of its properties
with open("pandas_demo.csv","r") as fi:
    df=pd.read_csv(fi)

# %%
print(type(df))
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     first_name      last_name                       email  gender  \
# 0         Otha         Gjerde      ogjerde0@biglobe.ne.jp  Female
# 1        Yance      Barnsdale   ybarnsdale1@reference.com    Male
# 2      Lazarus        MacNish    lmacnish2@altervista.org    Male
# 3       Monroe        Gwinnel       mgwinnel3@booking.com    Male
# 4      Gaspard      Gullivent       ggullivent4@wikia.com    Male
# ..         ...            ...                         ...     ...
# 995     Eduino  Alessandretti  ealessandrettirn@topsy.com    Male
# 996   Vivianna            Rix              vrixro@sun.com  Female
# 997    Donaugh         Emmert          demmertrp@sohu.com    Male
# 998   Reinaldo     O'Scannill      roscannillrq@desdev.cn    Male
# 999  Justinian          Goney  jgoneyrr@deliciousdays.com    Male
#
#           employer                     designation  \
# 0           Zomato                             NaN
# 1    Goldman Sachs                   Social Worker
# 2              TCS          Administrative Officer
# 3    Goldman Sachs                Technical Writer
# 4          Infosys             Clinical Specialist
# ..             ...                             ...
# 995        Infosys             Structural Engineer
# 996       Flipkart                Quality Engineer
# 997         Google              Recruiting Manager
# 998       Flipkart              VP Quality Control
# 999       Flipkart  Payment Adjustment Coordinator
#
#                                        university personal_phone      bank  \
# 0                           Sang Myung University   132-421-9138      HDFC
# 1            Fachhochschule Ravensburg-Weingarten   492-125-1131       SBI
# 2    California State University, Channel Islands   235-492-4252     ICICI
# 3                   St. Mary-of-the-Woods College            NaN     ICICI
# 4                 Islamic Azad University, Quchan   232-527-4054     ICICI
# ..                                            ...            ...       ...
# 995                     Universidad Adolfo Ibáñez   354-283-0381     ICICI
# 996                             Stonehill College   785-322-0735  Yes Bank
# 997        University of the South Pacific Centre   585-826-1040      HDFC
# 998                      Bulacan State University   268-203-9762     ICICI
# 999                            Arcadia University   173-701-0038  Yes Bank
#
#      birth_year  years_employed
# 0          1970            24.0
# 1          1960            32.0
# 2          1970            24.0
# 3          1982            14.4
# 4          1998             1.6
# ..          ...             ...
# 995        1978            17.6
# 996        1990             8.0
# 997        1962            30.4
# 998        1990             8.0
# 999        1978            17.6
#
# [1000 rows x 11 columns]

# %%
# We can change a column as index as well
df_col = pd.read_csv('pandas_demo.csv', index_col=0)
# or set index after reading a dataset as well
#df_col = df_col.set_index('last_name')
df_col
# Out:
#                                     email  gender       employer  \
# last_name
# Gjerde             ogjerde0@biglobe.ne.jp  Female         Zomato
# Barnsdale       ybarnsdale1@reference.com    Male  Goldman Sachs
# MacNish          lmacnish2@altervista.org    Male            TCS
# Gwinnel             mgwinnel3@booking.com    Male  Goldman Sachs
# Gullivent           ggullivent4@wikia.com    Male        Infosys
# ...                                   ...     ...            ...
# Alessandretti  ealessandrettirn@topsy.com    Male        Infosys
# Rix                        vrixro@sun.com  Female       Flipkart
# Emmert                 demmertrp@sohu.com    Male         Google
# O'Scannill         roscannillrq@desdev.cn    Male       Flipkart
# Goney          jgoneyrr@deliciousdays.com    Male       Flipkart
#
#                                   designation  \
# last_name
# Gjerde                                    NaN
# Barnsdale                       Social Worker
# MacNish                Administrative Officer
# Gwinnel                      Technical Writer
# Gullivent                 Clinical Specialist
# ...                                       ...
# Alessandretti             Structural Engineer
# Rix                          Quality Engineer
# Emmert                     Recruiting Manager
# O'Scannill                 VP Quality Control
# Goney          Payment Adjustment Coordinator
#
#                                                  university personal_phone  \
# last_name
# Gjerde                                Sang Myung University   132-421-9138
# Barnsdale              Fachhochschule Ravensburg-Weingarten   492-125-1131
# MacNish        California State University, Channel Islands   235-492-4252
# Gwinnel                       St. Mary-of-the-Woods College            NaN
# Gullivent                   Islamic Azad University, Quchan   232-527-4054
# ...                                                     ...            ...
# Alessandretti                     Universidad Adolfo Ibáñez   354-283-0381
# Rix                                       Stonehill College   785-322-0735
# Emmert               University of the South Pacific Centre   585-826-1040
# O'Scannill                         Bulacan State University   268-203-9762
# Goney                                    Arcadia University   173-701-0038
#
#                    bank  birth_year  years_employed
# last_name
# Gjerde             HDFC        1970            24.0
# Barnsdale           SBI        1960            32.0
# MacNish           ICICI        1970            24.0
# Gwinnel           ICICI        1982            14.4
# Gullivent         ICICI        1998             1.6
# ...                 ...         ...             ...
# Alessandretti     ICICI        1978            17.6
# Rix            Yes Bank        1990             8.0
# Emmert             HDFC        1962            30.4
# O'Scannill        ICICI        1990             8.0
# Goney          Yes Bank        1978            17.6
#
# [1000 rows x 9 columns]

# %%
#can even read json file.
#pd.read_json()

# %%
#convert back to csv/json
#pd.to_()

# %%
# head()
df.head(6)
# Out:
#   first_name  last_name                     email  gender       employer  \
# 0      Merle    Kenelin        mkenelin0@tamu.edu    Male          Aivee
# 1   Marigold    Haddock    mhaddock1@illinois.edu  Female      Realpoint
# 2      Nessy  Restorick       nrestorick2@com.com  Female          Npath
# 3    Madella   Lantuffe    mlantuffe3@comcast.net  Female  Thoughtbridge
# 4        Bax   Chaudron     bchaudron4@reddit.com    Male     Shuffletag
# 5    Yehudit   Schroder  yschroder5@tuttocitta.it    Male     Browsetype
#
#                      designation  \
# 0               Dental Hygienist
# 1               Technical Writer
# 2                    Engineer IV
# 3  Analog Circuit Design manager
# 4          VP Product Management
# 5         Senior Sales Associate
#
#                                          university personal_phone  \
# 0                      Concordia University, Irvine   158-563-8593
# 1  Universidad Michoacana de San Nicolás de Hidalgo   209-273-8218
# 2                                               NaN   530-775-4072
# 3               California State University, Fresno            NaN
# 4   Institute of Management and Business Technology   824-449-7742
# 5                         Universidad de Cienfuegos   530-514-8363
#
#      credit_card  birth_year  years_employed
# 0  visa-electron        1996             3.2
# 1            jcb        1997             2.4
# 2  visa-electron        1977            18.4
# 3            NaN        1982            14.4
# 4            jcb        1981            15.2
# 5            jcb        1991             7.2

# %%
df.tail(3)
# Out:
#     first_name    last_name                        email  gender     employer  \
# 997       Tana  Weatherhogg    tweatherhoggrp@flickr.com  Female       Tekfly
# 998    Mikaela     Raycroft  mraycroftrq@kickstarter.com  Female  Thoughtblab
# 999   Jeanette       Korpal        jkorpalrr@dropbox.com  Female       Agimba
#
#           designation                               university personal_phone  \
# 997           Actuary       Universitas Wijaya Kusuma Surabaya            NaN
# 998      Developer II             University of Maine, Augusta   276-706-4994
# 999  Senior Developer  Universidad Argentina "John F. Kennedy"            NaN
#
#              credit_card  birth_year  years_employed
# 997                  NaN        1981            15.2
# 998  diners-club-enroute        1994             4.8
# 999                  NaN        1988             9.6

# %%
df.columns
# Out:
# Index(['first_name', 'last_name', 'email', 'gender', 'employer', 'designation',
#        'university', 'personal_phone', 'credit_card', 'birth_year',
#        'years_employed'],
#       dtype='object')

# %%
df.dtypes
# Out:
# first_name         object
# last_name          object
# email              object
# gender             object
# employer           object
# designation        object
# university         object
# personal_phone     object
# credit_card        object
# birth_year          int64
# years_employed    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   first_name      1000 non-null   object
#  1   last_name       1000 non-null   object
#  2   email           1000 non-null   object
#  3   gender          1000 non-null   object
#  4   employer        1000 non-null   object
#  5   designation     939 non-null    object
#  6   university      892 non-null    object
#  7   personal_phone  783 non-null    object
#  8   bank            1000 non-null   object
#  9   birth_year      1000 non-null   int64
#  10  years_employed  1000 non-null   float64
# dtypes: float64(1), int64(1), object(9)
# memory usage: 86.1+ KB

# %%
df.describe()
# Out:
#         birth_year  years_employed
# count  1000.000000     1000.000000
# mean   1978.807000       16.954400
# std      11.341887        9.073509
# min    1960.000000        1.600000
# 25%    1969.000000        8.800000
# 50%    1979.000000       16.800000
# 75%    1989.000000       24.800000
# max    1998.000000       32.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.values
# Out:
# array([['Merle', 'Kenelin', 'mkenelin0@tamu.edu', ..., 'visa-electron',
#         1996, 3.2],
#        ['Marigold', 'Haddock', 'mhaddock1@illinois.edu', ..., 'jcb',
#         1997, 2.4],
#        ['Nessy', 'Restorick', 'nrestorick2@com.com', ...,
#         'visa-electron', 1977, 18.4],
#        ...,
#        ['Tana', 'Weatherhogg', 'tweatherhoggrp@flickr.com', ..., nan,
#         1981, 15.2],
#        ['Mikaela', 'Raycroft', 'mraycroftrq@kickstarter.com', ...,
#         'diners-club-enroute', 1994, 4.8],
#        ['Jeanette', 'Korpal', 'jkorpalrr@dropbox.com', ..., nan, 1988,
#         9.6]], dtype=object)

# %%
df.shape

# %% [markdown]
# #### Handling Duplicates

# %%
# Lets create a duplicate dataframe

# %%
# Drop duplicate

# %%
# How to drop duplicates? 
# Argument: keep

# %%
# You can create the dataframe object using the pd.DataFrame() constructor
# Here is one way

a=pd.DataFrame(index=range(0,10),columns=["A","B","C"],data=np.random.randint(1,10,(10,3)))
display(a)
# Out:
#    A  B  C
# 0  1  1  2
# 1  4  6  2
# 2  5  3  8
# 3  4  8  6
# 4  4  9  5
# 5  4  4  4
# 6  2  5  1
# 7  9  8  5
# 8  9  4  3
# 9  2  7  9

# %%
# Rename a column
#a.rename(columns={}, inplace)

# %%
#a.columns =

# %% [markdown]
# ## Reading data

# %% [markdown]
# ### The main interface

# %%
# Columns can be accessed using dot notation
df.birth_year
# Out:
# 0      1996
# 1      1997
# 2      1977
# 3      1982
# 4      1981
#        ...
# 995    1975
# 996    1977
# 997    1981
# 998    1994
# 999    1988
# Name: birth_year, Length: 1000, dtype: int64

# %%
# Columns can also be indexed - This will return a series
df["birth_year"]
# Out:
# 0      1970
# 1      1960
# 2      1970
# 3      1982
# 4      1998
#        ...
# 995    1978
# 996    1990
# 997    1962
# 998    1990
# 999    1978
# Name: birth_year, Length: 1000, dtype: int64

# %%
# Multiple columns can also be indexed - This will return a DataFrame
df[["first_name","birth_year"]]
# Out:
#     first_name  birth_year
# 0        Merle        1996
# 1     Marigold        1997
# 2        Nessy        1977
# 3      Madella        1982
# 4          Bax        1981
# ..         ...         ...
# 995   Christye        1975
# 996    Beltran        1977
# 997       Tana        1981
# 998    Mikaela        1994
# 999   Jeanette        1988
#
# [1000 rows x 2 columns]

# %%
# You can slice the rows by position
sliced=df[50:100]
# Note that the index still keeps the old numbers
# Thus index itself is kind of like a series - it's not just numbering from top to bottom.
# Actually, the index can be strings, dates anything
# Though for simplicity we will stick to integer indexes
print(sliced.index)
sliced.head()
# Out:
# RangeIndex(start=50, stop=100, step=1)
#    first_name  last_name                       email  gender     employer  \
# 50    Ceciley    Breakey   cbreakey1e@slideshare.net  Female      Camimbo
# 51     Walliw        Ley             wley1f@java.com  Female    Photofeed
# 52        Tod   McInteer  tmcinteer1g@shareasale.com    Male       Tambee
# 53   Charmine     Hearon       chearon1h@harvard.edu  Female  Topiclounge
# 54      Rikki  Verbrugge     rverbrugge1i@usnews.com    Male         Geba
#
#                  designation  \
# 50  Systems Administrator IV
# 51   Human Resources Manager
# 52       Software Consultant
# 53     Chief Design Engineer
# 54   Systems Administrator I
#
#                                            university personal_phone  \
# 50  Instituto Superior de Relações Internacionais ...   269-104-0079
# 51              Massachusetts Institute of Technology   363-227-4335
# 52                                                NaN   727-221-1362
# 53                                 Manchester College   478-235-7826
# 54         State Pedagogical University in Kryvyi Rih   111-278-6472
#
#    credit_card  birth_year  years_employed
# 50         jcb        1985            12.0
# 51         jcb        1985            12.0
# 52       laser        1980            16.0
# 53       laser        1984            12.8
# 54    bankcard        1982            14.4

# %%
# You can chain the two indexing style
df[:50][["first_name","last_name"]].head(5)
# Out:
#   first_name  last_name
# 0      Merle    Kenelin
# 1   Marigold    Haddock
# 2      Nessy  Restorick
# 3    Madella   Lantuffe
# 4        Bax   Chaudron

# %% [markdown]
# To summarise, indexing the dataframe directly like ``df[]`` allows
# * indexing a single column by name (or label)
# * indexing a list of columns by name
# * slicing of rows by position.
#
# Note that the following things doesn't work
# * indexing columns by position
# * indexing/slicing rows by name/label
#
# As we will see, there are two other interfaces that give us this functionality.

# %% [markdown]
# ### .loc

# %%
# Index a column by name same as before
# Notice that now you have to compulsarily provide a slice for the rows
df.loc[:,["first_name","last_name"]]
#df.loc[:, "first_name"]
# Out:
# 0           Otha
# 1          Yance
# 2        Lazarus
# 3         Monroe
# 4        Gaspard
#          ...
# 995       Eduino
# 996     Vivianna
# 997      Donaugh
# 998     Reinaldo
# 999    Justinian
# Name: first_name, Length: 1000, dtype: object

# %%
# But let's look at rows
sliced=df[50:100]
# Note the index goes from 50 to 100
sliced.head()
# Out:
#    first_name  last_name                       email  gender     employer  \
# 50    Ceciley    Breakey   cbreakey1e@slideshare.net  Female      Camimbo
# 51     Walliw        Ley             wley1f@java.com  Female    Photofeed
# 52        Tod   McInteer  tmcinteer1g@shareasale.com    Male       Tambee
# 53   Charmine     Hearon       chearon1h@harvard.edu  Female  Topiclounge
# 54      Rikki  Verbrugge     rverbrugge1i@usnews.com    Male         Geba
#
#                  designation  \
# 50  Systems Administrator IV
# 51   Human Resources Manager
# 52       Software Consultant
# 53     Chief Design Engineer
# 54   Systems Administrator I
#
#                                            university personal_phone  \
# 50  Instituto Superior de Relações Internacionais ...   269-104-0079
# 51              Massachusetts Institute of Technology   363-227-4335
# 52                                                NaN   727-221-1362
# 53                                 Manchester College   478-235-7826
# 54         State Pedagogical University in Kryvyi Rih   111-278-6472
#
#    credit_card  birth_year  years_employed
# 50         jcb        1985            12.0
# 51         jcb        1985            12.0
# 52       laser        1980            16.0
# 53       laser        1984            12.8
# 54    bankcard        1982            14.4

# %%
# We can index by position with the main interface - for example : 0:5 returns 50-54
sliced[0:5]
# Out:
#    first_name  last_name                       email  gender     employer  \
# 50    Ceciley    Breakey   cbreakey1e@slideshare.net  Female      Camimbo
# 51     Walliw        Ley             wley1f@java.com  Female    Photofeed
# 52        Tod   McInteer  tmcinteer1g@shareasale.com    Male       Tambee
# 53   Charmine     Hearon       chearon1h@harvard.edu  Female  Topiclounge
# 54      Rikki  Verbrugge     rverbrugge1i@usnews.com    Male         Geba
#
#                  designation  \
# 50  Systems Administrator IV
# 51   Human Resources Manager
# 52       Software Consultant
# 53     Chief Design Engineer
# 54   Systems Administrator I
#
#                                            university personal_phone  \
# 50  Instituto Superior de Relações Internacionais ...   269-104-0079
# 51              Massachusetts Institute of Technology   363-227-4335
# 52                                                NaN   727-221-1362
# 53                                 Manchester College   478-235-7826
# 54         State Pedagogical University in Kryvyi Rih   111-278-6472
#
#    credit_card  birth_year  years_employed
# 50         jcb        1985            12.0
# 51         jcb        1985            12.0
# 52       laser        1980            16.0
# 53       laser        1984            12.8
# 54    bankcard        1982            14.4

# %%
# But can we slice with respect to the original index?

# This will return an empty DF, as position is only upto 50
sliced[55:60]
# Out:
# Empty DataFrame
# Columns: [first_name, last_name, email, gender, employer, designation, university, personal_phone, credit_card, birth_year, years_employed]
# Index: []

# %%
# But this works well
sliced.loc[55:60]
# Out:
#    first_name last_name                          email  gender      employer  \
# 55     Ulrica  Widdison             uwiddison1j@va.gov  Female      Edgeblab
# 56       Gael   Paddock           gpaddock1k@yahoo.com    Male        Trilia
# 57     Kelwin   Goodger           kgoodger1l@github.io    Male       Yakidoo
# 58     Rustin    Jeffes          rjeffes1m@archive.org    Male  Jabbersphere
# 59     Barris   Kiossel          bkiossel1n@ebay.co.uk    Male      Feedfish
# 60    Dulcine  Coughlin  dcoughlin1o@blogtalkradio.com  Female       Meembee
#
#                      designation  \
# 55                       Actuary
# 56            Speech Pathologist
# 57              Product Engineer
# 58  Structural Analysis Engineer
# 59    Physical Therapy Assistant
# 60                  VP Marketing
#
#                                          university personal_phone  \
# 55                     Universidade Gregorio Semedo   132-476-4488
# 56                                    Touro College   565-720-1987
# 57                           University of Belgrade            NaN
# 58               Ecole Normale Supérieure de Cachan   211-888-9536
# 59  State University of New York College at Geneseo   340-166-6123
# 60                            University of Trieste   159-922-2968
#
#             credit_card  birth_year  years_employed
# 55  diners-club-enroute        1990             8.0
# 56              maestro        1960            32.0
# 57                  NaN        1987            10.4
# 58                 visa        1989             8.8
# 59                  jcb        1979            16.8
# 60                  jcb        1961            31.2

# %%
# Sometimes the original index is useful, especially if you want to modify the slice
# and assign to the original DataFrame (it automatically matches the indexes)

# But sometimes after a slice you want to reset the index
sliced=sliced.reset_index()
sliced
# Out:
#     index  first_name   last_name                             email  gender  \
# 0      50     Ceciley     Breakey         cbreakey1e@slideshare.net  Female
# 1      51      Walliw         Ley                   wley1f@java.com  Female
# 2      52         Tod    McInteer        tmcinteer1g@shareasale.com    Male
# 3      53    Charmine      Hearon             chearon1h@harvard.edu  Female
# 4      54       Rikki   Verbrugge           rverbrugge1i@usnews.com    Male
# 5      55      Ulrica    Widdison                uwiddison1j@va.gov  Female
# 6      56        Gael     Paddock              gpaddock1k@yahoo.com    Male
# 7      57      Kelwin     Goodger              kgoodger1l@github.io    Male
# 8      58      Rustin      Jeffes             rjeffes1m@archive.org    Male
# 9      59      Barris     Kiossel             bkiossel1n@ebay.co.uk    Male
# 10     60     Dulcine    Coughlin     dcoughlin1o@blogtalkradio.com  Female
# 11     61        Jeth     Dawbery                 jdawbery1p@nhs.uk    Male
# 12     62     Suellen    Rubertis         srubertis1q@instagram.com  Female
# 13     63   Jeannette    Britzius         jbritzius1r@123-reg.co.uk  Female
# 14     64    Theobald     Crookes               tcrookes1s@admin.ch    Male
# 15     65        Rufe     Milsted               rmilsted1t@etsy.com    Male
# 16     66     Phillip     Cristou             pcristou1u@cpanel.net    Male
# 17     67     Gusella      Ondrus             gondrus1v@cornell.edu  Female
# 18     68      Carlin     Carreck              ccarreck1w@nifty.com  Female
# 19     69  Maximilien     Marsham            mmarsham1x@samsung.com    Male
# 20     70         Lib    Snassell              lsnassell1y@sohu.com  Female
# 21     71        Lind      Loghan              lloghan1z@eepurl.com  Female
# 22     72      Jemima      Horrod                  jhorrod20@cbc.ca  Female
# 23     73      Krysta      Yanson              kyanson21@dion.ne.jp  Female
# 24     74        Dell      Inmett               dinmett22@imgur.com  Female
# 25     75      Shandy  De Andisie          sdeandisie23@samsung.com  Female
# 26     76   Brunhilda     Espinoy           bespinoy24@virginia.edu  Female
# 27     77      Elijah   MacConnel          emacconnel25@addthis.com    Male
# 28     78    Gloriane    Linneman  glinneman26@networksolutions.com  Female
# 29     79       Judon     Prudham           jprudham27@illinois.edu    Male
# 30     80       Corry    McArdell               cmcardell28@icq.com  Female
# 31     81      Ericka      Brason           ebrason29@moonfruit.com  Female
# 32     82       Brian    Domesday               bdomesday2a@unc.edu    Male
# 33     83     Arlinda        Peek                      apeek2b@g.co  Female
# 34     84       Robyn      Ventam            rventam2c@cbslocal.com  Female
# 35     85       Donni      Pagden                 dpagden2d@com.com  Female
# 36     86       Berry     Grocott             bgrocott2e@toplist.cz  Female
# 37     87      Barbra     Gilyatt     bgilyatt2f@huffingtonpost.com  Female
# 38     88       Berri       Milan             bmilan2g@bandcamp.com  Female
# 39     89        Wang  Malletratt        wmalletratt2h@virginia.edu    Male
# 40     90       Orion    Shevlane               oshevlane2i@unc.edu    Male
# 41     91      Joelly    Aucourte             jaucourte2j@lycos.com  Female
# 42     92       Vania     Peschet               vpeschet2k@1und1.de  Female
# 43     93     Wrennie      Melody     wmelody2l@creativecommons.org  Female
# 44     94    Jermaine      Peploe                 jpeploe2m@soup.io  Female
# 45     95     Rosanne    Goodburn           rgoodburn2n@youtube.com  Female
# 46     96     Viviyan     Refford           vrefford2o@bandcamp.com  Female
# 47     97       Cyndy        Lote             clote2p@csmonitor.com  Female
# 48     98        Ives     Kersley               ikersley2q@xrea.com    Male
# 49     99       Hyman      Belbin                hbelbin2r@webs.com    Male
#
#         employer                   designation  \
# 0        Camimbo      Systems Administrator IV
# 1      Photofeed       Human Resources Manager
# 2         Tambee           Software Consultant
# 3    Topiclounge         Chief Design Engineer
# 4           Geba       Systems Administrator I
# 5       Edgeblab                       Actuary
# 6         Trilia            Speech Pathologist
# 7        Yakidoo              Product Engineer
# 8   Jabbersphere  Structural Analysis Engineer
# 9       Feedfish    Physical Therapy Assistant
# 10       Meembee                  VP Marketing
# 11      Kanoodle           Account Coordinator
# 12       Voonder             Account Executive
# 13  Thoughtstorm          Software Engineer IV
# 14       Skalith                Tax Accountant
# 15  Chatterpoint                           NaN
# 16          Vipe              Media Manager IV
# 17   Browsedrive            Speech Pathologist
# 18        Agimba           Account Coordinator
# 19       Zoomdog                     Librarian
# 20       Dabtype    Physical Therapy Assistant
# 21        Kayveo           Software Consultant
# 22         Zoovu               Project Manager
# 23         Kwinu              Graphic Designer
# 24         Eabox           Staff Accountant IV
# 25       Zoomdog    Database Administrator III
# 26        Yacero              Senior Developer
# 27       Jaxspan              Senior Developer
# 28        Wikizz         VP Product Management
# 29        Agimba     Systems Administrator III
# 30        Divavu                  Engineer III
# 31       Teklist      Database Administrator I
# 32          Kazu                 VP Accounting
# 33         Zoovu                 Developer III
# 34      Photobug          Research Assistant I
# 35    Blognation          Programmer Analyst I
# 36   Thoughtblab                           NaN
# 37        Roodel         Safety Technician III
# 38       Dabfeed              Technical Writer
# 39     Buzzshare     Account Representative IV
# 40    Bubbletube  Human Resources Assistant IV
# 41       Nlounge                 Social Worker
# 42        Podcat       Human Resources Manager
# 43       Cogidoo                        Editor
# 44         Quire             Financial Analyst
# 45    Photospace            Environmental Tech
# 46          Kazu           Account Coordinator
# 47       Dablist           Electrical Engineer
# 48        Zooveo             Director of Sales
# 49     Topiczoom                           NaN
#
#                                            university personal_phone  \
# 0   Instituto Superior de Relações Internacionais ...   269-104-0079
# 1               Massachusetts Institute of Technology   363-227-4335
# 2                                                 NaN   727-221-1362
# 3                                  Manchester College   478-235-7826
# 4          State Pedagogical University in Kryvyi Rih   111-278-6472
# 5                        Universidade Gregorio Semedo   132-476-4488
# 6                                       Touro College   565-720-1987
# 7                              University of Belgrade            NaN
# 8                  Ecole Normale Supérieure de Cachan   211-888-9536
# 9     State University of New York College at Geneseo   340-166-6123
# 10                              University of Trieste   159-922-2968
# 11                                 Al-baha University   150-805-7969
# 12                                Istanbul University   134-260-6786
# 13                                                NaN   403-754-7577
# 14       International Institute for Higher Education   765-338-8267
# 15                  Azad Jammu and Kashmir University   180-769-4594
# 16                   Universidad Adventista del Plata   736-856-6092
# 17                      Universitas Widya Gama Malang   947-223-7831
# 18            University of California, Santa Barbara            NaN
# 19                                                NaN   200-602-8519
# 20                           Hansung University Seoul   479-600-9853
# 21           Hogere Zeevaartschool - Maritime Academy            NaN
# 22                                  Woosuk University   343-762-4763
# 23                                   Sohar University   300-542-8779
# 24                                 Université de Buéa   782-131-2174
# 25                         Laurus Technical Institute   991-798-5277
# 26                               Universität Bayreuth   924-377-6586
# 27                         Europäische Fachhochschule   737-722-4988
# 28                                                NaN   445-361-5518
# 29                                 University of Pecs            NaN
# 30                      International Budo University            NaN
# 31                          Universitas Sebelas Maret   500-519-5641
# 32  Rutgers, The State University of New Jersey - ...   672-953-3101
# 33  Moscow State University of Ecological Engineering   281-502-9894
# 34                       Universidad Valle del Momboy   685-141-3078
# 35                          Fukushima Medical College   226-791-9910
# 36  Moscow Technical University of Informatics and...   928-132-7416
# 37                           Musashino Art University   999-434-4520
# 38                        Chonnam National University   799-226-9930
# 39                                 Qingdao University   307-630-8373
# 40                Centre Universitaire de Technologie            NaN
# 41  Norwegian Teacher Academy for Studies in Relig...   910-762-9374
# 42                            Universiti Kuala Lumpur   939-645-2776
# 43                       Medical College of Wisconsin   417-444-7135
# 44  College of Osteopathic Medicine of the Pacific...   532-168-3288
# 45                              Chadron State College   218-538-4177
# 46                                      Berry College   145-661-8069
# 47                        Western Carolina University   747-858-5986
# 48   University of Mining and Geology "St. Ivan Rils"            NaN
# 49  Sikkim Manipal University of Health, Medical a...   392-955-6124
#
#                   credit_card  birth_year  years_employed
# 0                         jcb        1985            12.0
# 1                         jcb        1985            12.0
# 2                       laser        1980            16.0
# 3                       laser        1984            12.8
# 4                    bankcard        1982            14.4
# 5         diners-club-enroute        1990             8.0
# 6                     maestro        1960            32.0
# 7                         NaN        1987            10.4
# 8                        visa        1989             8.8
# 9                         jcb        1979            16.8
# 10                        jcb        1961            31.2
# 11                      laser        1987            10.4
# 12             china-unionpay        1970            24.0
# 13                        jcb        1971            23.2
# 14            americanexpress        1971            23.2
# 15        diners-club-enroute        1987            10.4
# 16                        jcb        1964            28.8
# 17                        jcb        1960            32.0
# 18                        NaN        1982            14.4
# 19                        jcb        1993             5.6
# 20                        jcb        1975            20.0
# 21                        NaN        1967            26.4
# 22                        jcb        1978            17.6
# 23            americanexpress        1976            19.2
# 24                    maestro        1961            31.2
# 25                     switch        1972            22.4
# 26                        jcb        1974            20.8
# 27                        jcb        1969            24.8
# 28               instapayment        1977            18.4
# 29                        NaN        1972            22.4
# 30                        NaN        1982            14.4
# 31              visa-electron        1988             9.6
# 32                 mastercard        1971            23.2
# 33          diners-club-us-ca        1962            30.4
# 34                 mastercard        1990             8.0
# 35                        jcb        1988             9.6
# 36                        jcb        1971            23.2
# 37                        jcb        1964            28.8
# 38                    maestro        1970            24.0
# 39                        jcb        1968            25.6
# 40                        NaN        1998             1.6
# 41              visa-electron        1974            20.8
# 42               instapayment        1983            13.6
# 43                        jcb        1976            19.2
# 44                        jcb        1966            27.2
# 45                 mastercard        1969            24.8
# 46  diners-club-carte-blanche        1960            32.0
# 47                        jcb        1968            25.6
# 48                        NaN        1991             7.2
# 49                        jcb        1961            31.2

# %% [markdown]
# ### .iloc

# %%
# This is good ol' numpy style indexing 
# By position on rows
# and By position on columns
df.iloc[5:7,:3]
# Out:
#   first_name     last_name                     email
# 5    Yehudit      Schroder  yschroder5@tuttocitta.it
# 6      Jareb  Jakoviljevic   jjakoviljevic6@dmoz.org

# %%
# A value
df.iloc[5,1]
# Out:
# 'Schroder'

# %%
# A series
df.iloc[:5,1]
# Out:
# 0      Kenelin
# 1      Haddock
# 2    Restorick
# 3     Lantuffe
# 4     Chaudron
# Name: last_name, dtype: object

# %%
# also a series
df.iloc[5,1:6]
# Out:
# last_name                      Schroder
# email          yschroder5@tuttocitta.it
# gender                             Male
# employer                     Browsetype
# designation      Senior Sales Associate
# Name: 5, dtype: object

# %%
#df.iloc[:,["first_name"]]

# %% [markdown]
# #### Handle Missing Values

# %% [markdown]
# There are two options in dealing with nulls:
#
# * Get rid of rows or columns with nulls
# * Replace nulls with non-null values, a technique known as imputation

# %%
# isnull() returns a DataFrame where each cell is either True or False depending on that cell's null status.
df.isnull()
# Out:
#      first_name  last_name  email  gender  employer  designation  university  \
# 0         False      False  False   False     False         True       False
# 1         False      False  False   False     False        False       False
# 2         False      False  False   False     False        False       False
# 3         False      False  False   False     False        False       False
# 4         False      False  False   False     False        False       False
# ..          ...        ...    ...     ...       ...          ...         ...
# 995       False      False  False   False     False        False       False
# 996       False      False  False   False     False        False       False
# 997       False      False  False   False     False        False       False
# 998       False      False  False   False     False        False       False
# 999       False      False  False   False     False        False       False
#
#      personal_phone   bank  birth_year  years_employed
# 0             False  False       False           False
# 1             False  False       False           False
# 2             False  False       False           False
# 3              True  False       False           False
# 4             False  False       False           False
# ..              ...    ...         ...             ...
# 995           False  False       False           False
# 996           False  False       False           False
# 997           False  False       False           False
# 998           False  False       False           False
# 999           False  False       False           False
#
# [1000 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# first_name          0
# last_name           0
# email               0
# gender              0
# employer            0
# designation        61
# university        108
# personal_phone    217
# bank                0
# birth_year          0
# years_employed      0
# dtype: int64

# %%
# Removing Null Values
df.dropna()
# Out:
#     first_name      last_name                       email  gender  \
# 1        Yance      Barnsdale   ybarnsdale1@reference.com    Male
# 2      Lazarus        MacNish    lmacnish2@altervista.org    Male
# 4      Gaspard      Gullivent       ggullivent4@wikia.com    Male
# 5        Karna         Climar         kclimar5@boston.com  Female
# 7        Peria       Beverage     pbeverage7@sakura.ne.jp  Female
# ..         ...            ...                         ...     ...
# 995     Eduino  Alessandretti  ealessandrettirn@topsy.com    Male
# 996   Vivianna            Rix              vrixro@sun.com  Female
# 997    Donaugh         Emmert          demmertrp@sohu.com    Male
# 998   Reinaldo     O'Scannill      roscannillrq@desdev.cn    Male
# 999  Justinian          Goney  jgoneyrr@deliciousdays.com    Male
#
#           employer                     designation  \
# 1    Goldman Sachs                   Social Worker
# 2              TCS          Administrative Officer
# 4          Infosys             Clinical Specialist
# 5         Flipkart                         Teacher
# 7         Flipkart              Analyst Programmer
# ..             ...                             ...
# 995        Infosys             Structural Engineer
# 996       Flipkart                Quality Engineer
# 997         Google              Recruiting Manager
# 998       Flipkart              VP Quality Control
# 999       Flipkart  Payment Adjustment Coordinator
#
#                                        university personal_phone      bank  \
# 1            Fachhochschule Ravensburg-Weingarten   492-125-1131       SBI
# 2    California State University, Channel Islands   235-492-4252     ICICI
# 4                 Islamic Azad University, Quchan   232-527-4054     ICICI
# 5                                Patna University   765-164-9307       SBI
# 7           Université Abou Bekr Belkaid, Tlemcen   876-185-6742       SBI
# ..                                            ...            ...       ...
# 995                     Universidad Adolfo Ibáñez   354-283-0381     ICICI
# 996                             Stonehill College   785-322-0735  Yes Bank
# 997        University of the South Pacific Centre   585-826-1040      HDFC
# 998                      Bulacan State University   268-203-9762     ICICI
# 999                            Arcadia University   173-701-0038  Yes Bank
#
#      birth_year  years_employed
# 1          1960            32.0
# 2          1970            24.0
# 4          1998             1.6
# 5          1968            25.6
# 7          1971            23.2
# ..          ...             ...
# 995        1978            17.6
# 996        1990             8.0
# 997        1962            30.4
# 998        1990             8.0
# 999        1978            17.6
#
# [658 rows x 11 columns]

# %%
# How to drop NA values?
# Argument: Axis

# %%
# Imputation
# Get a column => assign value for na celss => fillna()

# %% [markdown]
# ### Boolean indexing

# %%
# boolean indexing by column
print(df['birth_year']>=1990)
# multiple conditions
# using isin()

# %%
# boolean indexing by column
print(df['birth_year']>=1990)
only_90s_kids=df[df.birth_year>=1990]
print(only_90s_kids)
only_90s_kids=only_90s_kids[only_90s_kids.birth_year<=2000]
print(len(only_90s_kids))
only_90s_kids.head(5)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 995    False
# 996     True
# 997    False
# 998     True
# 999    False
# Name: birth_year, Length: 1000, dtype: bool
#     first_name   last_name                        email  gender  \
# 4      Gaspard   Gullivent        ggullivent4@wikia.com    Male
# 11     Hermann       Dewen           hdewenb@hao123.com    Male
# 14       Anica  MacIlhargy         amacilhargye@nih.gov  Female
# 18       Hermy  Lambertini   hlambertinii@bloglovin.com    Male
# 20        Amii   Sacchetti         asacchettik@ucla.edu  Female
# ..         ...         ...                          ...     ...
# 981     Gillie    Jikovsky         gjikovskyr9@usda.gov  Female
# 986      Helge     Gambell      hgambellre@netvibes.com  Female
# 989   Carolyne  Reitenbach  creitenbachrh@canalblog.com  Female
# 996   Vivianna         Rix               vrixro@sun.com  Female
# 998   Reinaldo  O'Scannill       roscannillrq@desdev.cn    Male
#
#           employer             designation  \
# 4          Infosys     Clinical Specialist
# 11          Zomato      VP Quality Control
# 14          Zomato      Analyst Programmer
# 18             TCS      Environmental Tech
# 20         Infosys      Recruiting Manager
# ..             ...                     ...
# 981       Flipkart              Engineer I
# 986  Goldman Sachs                   Nurse
# 989         Google  Senior Sales Associate
# 996       Flipkart        Quality Engineer
# 998       Flipkart      VP Quality Control
#
#                                             university personal_phone  \
# 4                      Islamic Azad University, Quchan   232-527-4054
# 11                       Universidade de Caxias do Sul            NaN
# 14                                  Capitol University   578-536-7874
# 18                              Warnborough University   715-183-6507
# 20                                 Hyupsung University            NaN
# ..                                                 ...            ...
# 981  Fachhochschule Rottenburg, Hochschule für Fors...            NaN
# 986                        Yildiz Technical University   548-680-5479
# 989                  Technological University (Pinlon)   703-644-6126
# 996                                  Stonehill College   785-322-0735
# 998                           Bulacan State University   268-203-9762
#
#          bank  birth_year  years_employed
# 4       ICICI        1998             1.6
# 11   Yes Bank        1990             8.0
# 14   Yes Bank        1997             2.4
# 18        SBI        1994             4.8
# 20      ICICI        1997             2.4
# ..        ...         ...             ...
# 981      HDFC        1993             5.6
# 986  Yes Bank        1990             8.0
# 989      HDFC        1996             3.2
# 996  Yes Bank        1990             8.0
# 998     ICICI        1990             8.0
#
# [225 rows x 11 columns]
# 225
#    first_name   last_name                       email  gender employer  \
# 4     Gaspard   Gullivent       ggullivent4@wikia.com    Male  Infosys
# 11    Hermann       Dewen          hdewenb@hao123.com    Male   Zomato
# 14      Anica  MacIlhargy        amacilhargye@nih.gov  Female   Zomato
# 18      Hermy  Lambertini  hlambertinii@bloglovin.com    Male      TCS
# 20       Amii   Sacchetti        asacchettik@ucla.edu  Female  Infosys
#
#             designation                       university personal_phone  \
# 4   Clinical Specialist  Islamic Azad University, Quchan   232-527-4054
# 11   VP Quality Control    Universidade de Caxias do Sul            NaN
# 14   Analyst Programmer               Capitol University   578-536-7874
# 18   Environmental Tech           Warnborough University   715-183-6507
# 20   Recruiting Manager              Hyupsung University            NaN
#
#         bank  birth_year  years_employed
# 4      ICICI        1998             1.6
# 11  Yes Bank        1990             8.0
# 14  Yes Bank        1997             2.4
# 18       SBI        1994             4.8
# 20     ICICI        1997             2.4

# %% [markdown]
# ## Setting data

# %%
# The most common operation : computing a new column based on other columns

only_90s_kids["age"] = 2020 - only_90s_kids.birth_year

# Notice how the index is preserved
only_90s_kids.head(5)
# Out:
#    first_name   last_name                     email  gender     employer  \
# 0       Merle     Kenelin        mkenelin0@tamu.edu    Male        Aivee
# 1    Marigold     Haddock    mhaddock1@illinois.edu  Female    Realpoint
# 5     Yehudit    Schroder  yschroder5@tuttocitta.it    Male   Browsetype
# 35    Karlens      Dubois     kduboisz@bandcamp.com    Male  Shufflebeat
# 40    Riordan  Jacobowits    rjacobowits14@lulu.com    Male   Realbridge
#
#                 designation                                        university  \
# 0          Dental Hygienist                      Concordia University, Irvine
# 1          Technical Writer  Universidad Michoacana de San Nicolás de Hidalgo
# 5    Senior Sales Associate                         Universidad de Cienfuegos
# 35       Recruiting Manager                                   Shorter College
# 40  GIS Technical Architect         California State University, Monterey Bay
#
#    personal_phone    credit_card  birth_year  years_employed  age
# 0    158-563-8593  visa-electron        1996             3.2   24
# 1    209-273-8218            jcb        1997             2.4   23
# 5    530-514-8363            jcb        1991             7.2   29
# 35   615-785-9997            jcb        1996             3.2   24
# 40   568-830-5897            jcb        1991             7.2   29

# %%
# You could even have assigned it to the original df

# but let's copy it first ;)
fresh_df=df.copy()

# All the correct indices will be filled otherwise it will be set as NaN.
# This is one of the use cases of having a separate index object
# vs just position numbering like numpy
fresh_df["age"] = 2020 - only_90s_kids.birth_year
fresh_df
# Out:
#     first_name    last_name                        email  gender  \
# 0        Merle      Kenelin           mkenelin0@tamu.edu    Male
# 1     Marigold      Haddock       mhaddock1@illinois.edu  Female
# 2        Nessy    Restorick          nrestorick2@com.com  Female
# 3      Madella     Lantuffe       mlantuffe3@comcast.net  Female
# 4          Bax     Chaudron        bchaudron4@reddit.com    Male
# ..         ...          ...                          ...     ...
# 995   Christye      Boreham        cborehamrn@rambler.ru  Female
# 996    Beltran         Elvy           belvyro@forbes.com    Male
# 997       Tana  Weatherhogg    tweatherhoggrp@flickr.com  Female
# 998    Mikaela     Raycroft  mraycroftrq@kickstarter.com  Female
# 999   Jeanette       Korpal        jkorpalrr@dropbox.com  Female
#
#           employer                    designation  \
# 0            Aivee               Dental Hygienist
# 1        Realpoint               Technical Writer
# 2            Npath                    Engineer IV
# 3    Thoughtbridge  Analog Circuit Design manager
# 4       Shuffletag          VP Product Management
# ..             ...                            ...
# 995    Twitterlist              Director of Sales
# 996         Skaboo            Software Consultant
# 997         Tekfly                        Actuary
# 998    Thoughtblab                   Developer II
# 999         Agimba               Senior Developer
#
#                                            university personal_phone  \
# 0                        Concordia University, Irvine   158-563-8593
# 1    Universidad Michoacana de San Nicolás de Hidalgo   209-273-8218
# 2                                                 NaN   530-775-4072
# 3                 California State University, Fresno            NaN
# 4     Institute of Management and Business Technology   824-449-7742
# ..                                                ...            ...
# 995                                               NaN   469-619-6625
# 996              Tabari Institute of Higher Education   124-721-6651
# 997                Universitas Wijaya Kusuma Surabaya            NaN
# 998                      University of Maine, Augusta   276-706-4994
# 999           Universidad Argentina "John F. Kennedy"            NaN
#
#              credit_card  birth_year  years_employed   age
# 0          visa-electron        1996             3.2  24.0
# 1                    jcb        1997             2.4  23.0
# 2          visa-electron        1977            18.4   NaN
# 3                    NaN        1982            14.4   NaN
# 4                    jcb        1981            15.2   NaN
# ..                   ...         ...             ...   ...
# 995                  jcb        1975            20.0   NaN
# 996                  jcb        1977            18.4   NaN
# 997                  NaN        1981            15.2   NaN
# 998  diners-club-enroute        1994             4.8  26.0
# 999                  NaN        1988             9.6   NaN
#
# [1000 rows x 12 columns]

# %%
# You can of course set values at a particular position
print(fresh_df.iloc[0,-1]) 
fresh_df.iloc[0,-1]=29
print(fresh_df.iloc[0,-1])
# Out:
# 29.0
# 29.0

# %% [markdown]
# # Data Investigation Example 1

# %% [markdown]
# Let's make a set of questions and then see how we can answer them by using pandas

# %% [markdown]
# * Who are the employers?
# * What is the employee count of each employer?
# * What is the % of Male vs Female employees for each company?
# * What is the average age of an employee for each company?
# * Which bank is most popular in each company?

# %%
df[:]["employer"].drop_duplicates()
# Out:
# 0            Zomato
# 1     Goldman Sachs
# 2               TCS
# 4           Infosys
# 5          Flipkart
# 31           Google
# Name: employer, dtype: object

# %%
grps=df.groupby(by="employer")

# %%
grps.groups
# Out:
# {'Flipkart': Int64Index([  5,   7,  13,  21,  25,  27,  33,  40,  50,  55,
#              ...
#              957, 962, 966, 970, 981, 985, 991, 996, 998, 999],
#             dtype='int64', length=167),
#  'Goldman Sachs': Int64Index([  1,   3,   6,  15,  16,  22,  23,  24,  26,  36,
#              ...
#              951, 956, 960, 961, 973, 974, 975, 982, 986, 988],
#             dtype='int64', length=168),
#  'Google': Int64Index([ 31,  34,  43,  60,  62,  64,  68,  69,  70,  75,
#              ...
#              924, 932, 934, 950, 958, 964, 978, 979, 989, 997],
#             dtype='int64', length=186),
#  'Infosys': Int64Index([  4,   8,  20,  29,  32,  35,  38,  48,  56,  65,
#              ...
#              953, 954, 968, 969, 971, 977, 980, 987, 990, 995],
#             dtype='int64', length=162),
#  'TCS': Int64Index([  2,  18,  19,  30,  39,  42,  45,  51,  53,  54,
#              ...
#              931, 933, 935, 939, 949, 952, 963, 965, 983, 993],
#             dtype='int64', length=168),
#  'Zomato': Int64Index([  0,   9,  10,  11,  12,  14,  17,  28,  49,  57,
#              ...
#              925, 945, 955, 959, 967, 972, 976, 984, 992, 994],
#             dtype='int64', length=149)}

# %%
# Notice that it counts non-empty values
grps.count()
# Out:
#                first_name  last_name  email  gender  designation  university  \
# employer
# Flipkart              167        167    167     167          158         155
# Goldman Sachs         168        168    168     168          151         152
# Google                186        186    186     186          175         163
# Infosys               162        162    162     162          155         144
# TCS                   168        168    168     168          163         149
# Zomato                149        149    149     149          137         129
#
#                personal_phone  bank  birth_year  years_employed
# employer
# Flipkart                  134   167         167             167
# Goldman Sachs             131   168         168             168
# Google                    146   186         186             186
# Infosys                   120   162         162             162
# TCS                       139   168         168             168
# Zomato                    113   149         149             149

# %%
# So how to get the number of rows in each group?

# One way:
fresh=df.copy()
fresh["id"]=np.arange(0,len(fresh))
display(fresh.groupby("employer").count()["id"])

# Another simpler way :)
display(grps.size())

# Remember a little creativity goes a long way
# Out:
# employer
# Flipkart         167
# Goldman Sachs    168
# Google           186
# Infosys          162
# TCS              168
# Zomato           149
# Name: id, dtype: int64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-69a76af5a0aa> in <module>
#       7
#       8 # Another simpler way :)
# ----> 9 display(grps.size())
#      10
#      11 # Remember a little creativity goes a long way
#
# NameError: name 'grps' is not defined

# %%
grps=df.groupby(by=["employer","gender"])

# This is an example of a hierarchical index for a series
display(grps.size())
# Out:
# employer       gender
# Flipkart       Female    86
#                Male      81
# Goldman Sachs  Female    85
#                Male      83
# Google         Female    91
#                Male      95
# Infosys        Female    82
#                Male      80
# TCS            Female    92
#                Male      76
# Zomato         Female    72
#                Male      77
# dtype: int64

# %%
counts=pd.DataFrame(grps.size())
print(counts.to_records())
counts=pd.DataFrame(counts.to_records())
display(counts)
# Out:
# [('Flipkart', 'Female', 86) ('Flipkart', 'Male', 81)
#  ('Goldman Sachs', 'Female', 85) ('Goldman Sachs', 'Male', 83)
#  ('Google', 'Female', 91) ('Google', 'Male', 95) ('Infosys', 'Female', 82)
#  ('Infosys', 'Male', 80) ('TCS', 'Female', 92) ('TCS', 'Male', 76)
#  ('Zomato', 'Female', 72) ('Zomato', 'Male', 77)]
#          employer  gender   0
# 0        Flipkart  Female  86
# 1        Flipkart    Male  81
# 2   Goldman Sachs  Female  85
# 3   Goldman Sachs    Male  83
# 4          Google  Female  91
# 5          Google    Male  95
# 6         Infosys  Female  82
# 7         Infosys    Male  80
# 8             TCS  Female  92
# 9             TCS    Male  76
# 10         Zomato  Female  72
# 11         Zomato    Male  77

# %%
with_age=df.copy()
with_age["age"]=2020 - with_age.birth_year
with_age[["employer","age"]].groupby("employer").mean()
# Out:
#                      age
# employer
# Flipkart       41.616766
# Goldman Sachs  41.047619
# Google         43.000000
# Infosys        42.382716
# TCS            39.005952
# Zomato         42.651007

# %%
temp=df[["employer","bank"]].groupby(["employer","bank"]).size()
temp=pd.DataFrame(pd.DataFrame(temp).to_records())
temp=temp.rename(columns={"0":"count"})
temp=temp.sort_values('count',ascending=False)
display(temp)
# Out:
#          employer      bank  count
# 8          Google      HDFC     55
# 10         Google       SBI     55
# 14        Infosys       SBI     51
# 2        Flipkart       SBI     47
# 0        Flipkart      HDFC     46
# 17            TCS     ICICI     45
# 18            TCS       SBI     45
# 4   Goldman Sachs      HDFC     44
# 22         Zomato       SBI     44
# 16            TCS      HDFC     43
# 6   Goldman Sachs       SBI     42
# 7   Goldman Sachs  Yes Bank     42
# 11         Google  Yes Bank     42
# 13        Infosys     ICICI     42
# 5   Goldman Sachs     ICICI     40
# 1        Flipkart     ICICI     39
# 21         Zomato     ICICI     37
# 23         Zomato  Yes Bank     37
# 15        Infosys  Yes Bank     36
# 19            TCS  Yes Bank     35
# 3        Flipkart  Yes Bank     35
# 9          Google     ICICI     34
# 12        Infosys      HDFC     33
# 20         Zomato      HDFC     31

# %%
# Some more creativity
display(temp.drop_duplicates(subset=["employer"],keep="first"))
# Out:
#          employer   bank  count
# 8          Google   HDFC     55
# 14        Infosys    SBI     51
# 2        Flipkart    SBI     47
# 17            TCS  ICICI     45
# 4   Goldman Sachs   HDFC     44
# 22         Zomato    SBI     44
